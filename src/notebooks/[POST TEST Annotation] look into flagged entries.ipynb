# %%
import os
import yaml
import pickle

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from matplotlib import pyplot as plt
import seaborn as sns

# %%
with open('../../data/post_test/some_annotated.pkl', 'rb') as fp:
    some = pickle.load(fp)

# %%
some.columns
# Out:
# Index(['username', 'start_time', 'exploration_time', 'ranking_task_time',
#        'ranking', 'ranking_confidence', 'ranking_time', 'q1', 'q1_conf',
#        'q1_time', 'q2', 'q2_conf', 'q2_time', 'q3', 'q3_conf', 'q3_time', 'q4',
#        'q4_conf', 'q4_time', 'q5_colour0', 'q5_colour1', 'q5_colour2',
#        'q5_colour3', 'q5_time', 'q6_colour0', 'q6_colour1', 'q6_colour2',
#        'q6_colour3', 'q6_time', 'q7_colour0', 'q7_colour1', 'q7_colour2',
#        'q7_colour3', 'q7_time', 'q8_colour0', 'q8_colour1', 'q8_colour2',
#        'q8_colour3', 'q8_time', 'formula', 'fomula_conf', 'formula_time',
#        'notes_text', 'notes_math', 'notes_table', 'notes_diag', 'notes_time',
#        'beerslaw', 'beerslaw_conf', 'beerslaw_time', 'problem_ranking',
#        'problem_conf', 'problem_time', 'feedback_entertain',
#        'feedback_difficult', 'feedback_good', 'feedback_bad', 'feedback',
#        'feedback_time', 'experiment_time', 'status', 'session', 'version',
#        'numerical_status', 'language', 'field', 'level', 'year', 'consent',
#        'gender', 'label_q1', 'flag_q1_label', 'q2_label', 'flag_q2_label',
#        'label_q3', 'flag_label_q3', 'label_q4', 'flag_label_q4'],
#       dtype='object')

# %% [markdown]
# # Numerical Post Test Questions

# %%
q1 = some[some['flag_q1_label'] == 1]
q2 = some[some['flag_q2_label'] == 1]
q3 = some[some['flag_label_q3'] == 1]
q4 = some[some['flag_label_q4'] == 1]

# %%
q1
# Out:
#      username            start_time      exploration_time  \
# 91   sm8sfpcg  {'time': 1624871146}  {'time': 1624871476}
# 449  favvtnnf  {'time': 1624455187}  {'time': 1624455521}
# 453  k7p5eryf  {'time': 1624626653}  {'time': 1624626748}
#
#         ranking_task_time ranking ranking_confidence ranking_time  \
# 91   {'time': 1624871789}    3021                 90   1624871814
# 449  {'time': 1624455806}    3021                  0   1624455856
# 453  {'time': 1624626980}    2310                100   1624627033
#
#                                                     q1 q1_conf     q1_time  \
# 91   Eine halb so grosse Extinktion, da, je breiter...      95  1624872044
# 449         74%\r\n\r\nDie Fragen sind unklar gestellt      55  1624455899
# 453  0.74/2 = 0.37\r\n1 - 0.37 = 0.63 = T\r\n-log(T...     100  1624627212
#
#                                                     q2 q2_conf     q2_time  \
# 91   Eine dreifache Extinktion, da die Konzentratio...      85  1624872154
# 449                                               0.25       0  1624455959
# 453  Warum sollte man den Unterricht nicht lassen, ...     100  1624627343
#
#                                                     q3 q3_conf     q3_time  \
# 91   die gleiche... da zuerst der Abstand halbiert ...      85  1624872228
# 449                                  ich weis es nicht       0  1624456074
# 453                                                  -      55  1624627364
#
#                                                     q4 q4_conf     q4_time  \
# 91   Länge wird vervierfacht: 0.6*4 =2.4\r\nKonzent...      90  1624872330
# 449                                     weis ich nicht      45  1624456124
# 453                                                 --      70  1624627372
#
#     q5_colour0 q5_colour1 q5_colour2 q5_colour3     q5_time q6_colour0  \
# 91           5         15         20         60  1624872448          0
# 449         25         25         25         25  1624456715          5
# 453          5          5          5         85  1624627403        100
#
#     q6_colour1 q6_colour2 q6_colour3     q6_time q7_colour0 q7_colour1  \
# 91           0         20         80  1624872476    missing    missing
# 449         10         25         60  1624456774    missing    missing
# 453          0          0          0  1624627516    missing    missing
#
#     q7_colour2 q7_colour3  q7_time q8_colour0 q8_colour1 q8_colour2  \
# 91     missing    missing  missing    missing    missing    missing
# 449    missing    missing  missing    missing    missing    missing
# 453    missing    missing  missing    missing    missing    missing
#
#     q8_colour3  q8_time                                            formula  \
# 91     missing  missing  je höher Konzentration desto höher die Extinkt...
# 449    missing  missing                                      keine Ahnung
# 453    missing  missing                                                 --
#
#     fomula_conf formula_time notes_text notes_math notes_table notes_diag  \
# 91           75   1624872562
# 449           0   1624456812
# 453          60   1624627529
#
#      notes_time                                  beerslaw beerslaw_conf  \
# 91   1624872722  Kaum, schon gehört aber nicht angewendet
# 449  1624456833                                fast nicht
# 453  1624627539                                        --
#
#     beerslaw_time                                    problem_ranking  \
# 91     1624872767  [Co(No3)2: Cobalt (II) nitrate, CoCl2: Cobalt ...
# 449    1624456847  [Ich weiss nicht, Ich weiss nicht, Ich weiss n...
# 453    1624627555                                             [, , ]
#
#     problem_conf problem_time feedback_entertain feedback_difficult  \
# 91   wrong field   1624873404                 75                 75
# 449  wrong field   1624457678            missing            missing
# 453  wrong field   1624627690            missing            missing
#
#                                         feedback_good  \
# 91   Dass die Simulationen simpel zu begreifen waren.
# 449                                           missing
# 453                                           missing
#
#                                           feedback_bad     feedback  \
# 91   Dass man nicht wieder zu den Simulationen zurü...  wrong field
# 449                                            missing      missing
# 453                                            missing      missing
#
#     feedback_time experiment_time    status     session  version  \
# 91     1624873550      1624873552  complete  Session 28        3
# 449       missing         missing  feedback  Session 32        3
# 453       missing         missing  feedback  Session 23        3
#
#     numerical_status language      field                 level year  consent  \
# 91                18  Deutsch  Chemistry  Apprenticeship (Low)  1st      1.0
# 449               16  Deutsch  Chemistry  Apprenticeship (Low)  2nd      1.0
# 453               16  Deutsch    Biology  Apprenticeship (Low)  2nd      1.0
#
#      gender   label_q1  flag_q1_label   q2_label  flag_q2_label label_q3  \
# 91      1.0    smaller            1.0    correct            NaN  correct
# 449     1.0       same            1.0    smaller            NaN     nans
# 453     4.0  unrelated            1.0  unrelated            1.0     nans
#
#      flag_label_q3 label_q4  flag_label_q4
# 91             NaN  correct            NaN
# 449            NaN     nans            NaN
# 453            NaN     nans            NaN

# %%
q2
# Out:
#      username            start_time      exploration_time  \
# 50   mcjaj2aj  {'time': 1624263236}  {'time': 1624264056}
# 129  e8zdytr2  {'time': 1624455155}  {'time': 1624455311}
# 153  cb6wcvyn  {'time': 1631170462}  {'time': 1631170656}
# 183  bebyve9b  {'time': 1621600645}  {'time': 1621600869}
# 240  gu7jpyum  {'time': 1624351669}  {'time': 1624352199}
# 294  h9t9mxtx  {'time': 1631265596}  {'time': 1631266143}
# 345  n3977erj  {'time': 1632309804}  {'time': 1632309831}
# 453  k7p5eryf  {'time': 1624626653}  {'time': 1624626748}
#
#         ranking_task_time ranking ranking_confidence ranking_time  \
# 50   {'time': 1624264596}    3210                 55   1624264635
# 129  {'time': 1624455488}    0213                 25   1624455542
# 153  {'time': 1631170898}    2130                 30   1631170940
# 183  {'time': 1621601960}    0231                 50   1621601987
# 240  {'time': 1624352420}    3201                100   1624352502
# 294  {'time': 1631266740}    1023                 10   1631266817
# 345  {'time': 1632309846}    3012                 60   1632309985
# 453  {'time': 1624626980}    2310                100   1624627033
#
#                                                     q1 q1_conf     q1_time  \
# 50   0,37 parce que la cuve diminue par la moitié d...      45  1624264845
# 129                                               0,37       0  1624455698
# 153                                      0.74/2 = 0.37      50  1631171010
# 183                                            0.37 nm      40  1621602100
# 240                                               1.59     100  1624352615
# 294                                           A = 0.37      10  1631267203
# 345                                               0.74      55  1632310044
# 453  0.74/2 = 0.37\r\n1 - 0.37 = 0.63 = T\r\n-log(T...     100  1624627212
#
#                                                     q2 q2_conf     q2_time  \
# 50   0,159 car la concentration est trois fois plus...      50  1624265006
# 129                                                  3       0  1624455731
# 153  Je ne sais pas je n'ai pas vraiment eu ce genr...     100  1631171141
# 183                                            1.59 nm      40  1621602177
# 240                                                  3     100  1624352702
# 294  A= elc\r\nA = 5.3 x 1 x 100 = 1.59 \r\n\r\n0.5...      15  1631267477
# 345  il faut appliquer la loi de lambert  beer, A=c...      25  1632310305
# 453  Warum sollte man den Unterricht nicht lassen, ...     100  1624627343
#
#                                                     q3 q3_conf     q3_time  \
# 50   0,96 vu que la concentration est doublée et la...      60  1624265133
# 129                                               0,96      10  1624455955
# 153                                            La même     100  1631171166
# 183                                            1.44 nm      25  1621602251
# 240                                               0.48     100  1624352733
# 294                                           A= 0.96       15  1631267639
# 345             distance plus courte donc absorbe plus      25  1632310406
# 453                                                  -      55  1624627364
#
#                                                     q4 q4_conf     q4_time  \
# 50   0,80 car la concentration et la distance chang...      40  1624265220
# 129                                                0,8      40  1624455988
# 153                                     Je ne sais pas     100  1631171203
# 183                                                abc      35  1621602414
# 240                                                2.4     100  1624352753
# 294                                             A= 0.8      20  1631267865
# 345                                        aucune idée      55  1632310454
# 453                                                 --      70  1624627372
#
#     q5_colour0 q5_colour1 q5_colour2 q5_colour3     q5_time q6_colour0  \
# 50          25          0          0         75  1624265369          0
# 129          0          0        100          0  1624456080        100
# 153         50         30         15          5  1631171316         50
# 183         10         90          0          0  1621602464          0
# 240        100          0          0          0  1624352909          0
# 294         40         60          0          0  1631267920          0
# 345         50         10         20         20  1632310573         95
# 453          5          5          5         85  1624627403        100
#
#     q6_colour1 q6_colour2 q6_colour3     q6_time q7_colour0 q7_colour1  \
# 50          50         50          0  1624265444    missing    missing
# 129          0          0          0  1624456090    missing    missing
# 153         35         10          5  1631171422    missing    missing
# 183          0          0        100  1621602476    missing    missing
# 240          0          0        100  1624352978    missing    missing
# 294          0         10         90  1631267948    missing    missing
# 345          5          0          0  1632310648    missing    missing
# 453          0          0          0  1624627516    missing    missing
#
#     q7_colour2 q7_colour3  q7_time q8_colour0 q8_colour1 q8_colour2  \
# 50     missing    missing  missing    missing    missing    missing
# 129    missing    missing  missing    missing    missing    missing
# 153    missing    missing  missing    missing    missing    missing
# 183    missing    missing  missing    missing    missing    missing
# 240    missing    missing  missing    missing    missing    missing
# 294    missing    missing  missing    missing    missing    missing
# 345    missing    missing  missing    missing    missing    missing
# 453    missing    missing  missing    missing    missing    missing
#
#     q8_colour3  q8_time                                            formula  \
# 50     missing  missing  La concentration fait varier l'absorbance car ...
# 129    missing  missing                                          c=E/(e*d)
# 153    missing  missing  L'absorbance est égale à la concentration mult...
# 183    missing  missing                                          mvrorjgjg
# 240    missing  missing  Je höher die Konzentration, desto kleiner ist ...
# 294    missing  missing  A= ExCxl \r\n\r\nC: plus la concentration est ...
# 345    missing  missing  A= c X d X e \r\nla longueur d'onde va changer...
# 453    missing  missing                                                 --
#
#     fomula_conf formula_time notes_text  \
# 50           45   1624265733
# 129          90   1624456203
# 153         100   1631171629
# 183          30   1621602490     fkfkfg
# 240         100   1624353197
# 294           5   1631268121
# 345          80   1632310792
# 453          60   1624627529
#
#                                   notes_math notes_table notes_diag  \
# 50
# 129
# 153
# 183
# 240  E_Lambda=Intensität . Konzentration\r\n
# 294                                    A=elc
# 345
# 453
#
#      notes_time                              beerslaw beerslaw_conf  \
# 50   1624265761  Oui car on l'utilise souvent au labo
# 129  1624456214                                 Etwas
# 153  1631171666                                   Oui
# 183  1621602506                             ein Wenig
# 240  1624353339                     Sehr gut vertraut
# 294  1631268133                                Oui...
# 345  1632310805                                  oui
# 453  1624627539                                    --
#
#     beerslaw_time                                    problem_ranking  \
# 50     1624265790   [Je ne sais pas, Je ne sais pas, Je ne sais pas]
# 129    1624456291                  [Drink mix, Drink mix, Drink mix]
# 153    1631171673   [Je ne sais pas, Je ne sais pas, Je ne sais pas]
# 183    1621602524  [K2CrO4: Potassium chromate, KMnO4: Potassium ...
# 240    1624353358  [K2Cr2O7: Potassium dichromate, K2CrO4: Potass...
# 294    1631268142  [K2Cr2O7: Potassium dichromate, CuSO4: Copper ...
# 345    1632310815  [KMnO4: Potassium permanganate, Co(No3)2: Coba...
# 453    1624627555                                             [, , ]
#
#     problem_conf problem_time feedback_entertain feedback_difficult  \
# 50   wrong field   1624266035                 80                 45
# 129  wrong field   1624456674                 40                 80
# 153  wrong field   1631171743                 50                 70
# 183  wrong field   1621602588                 60                 50
# 240  wrong field   1624353508                100                 45
# 294  wrong field   1631268348                 75                 80
# 345  wrong field   1632310951                 45                100
# 453  wrong field   1624627690            missing            missing
#
#                                          feedback_good  \
# 50                                           le schéma
# 129                                                  -
# 153                                   C'est très imagé
# 183  Die spielerische Herangehensweise und die Mögl...
# 240                                   Die Wellenlängen
# 294  Cela me montre que je dois revoir mes cours de...
# 345                                         les images
# 453                                            missing
#
#                                           feedback_bad     feedback  \
# 50   le fait de ne pas pouvoir retourner en arrière...  wrong field
# 129                                                  -  wrong field
# 153  Le monde des sciences est extrêmement vaste et...  wrong field
# 183  Zeit zu kurz bemessen um sich wirklich mit der...  wrong field
# 240                                              Keins  wrong field
# 294              De ne pas pouvoir revenir en arrière   wrong field
# 345  je n'ai pas eu le test préalable pour les expl...  wrong field
# 453                                            missing      missing
#
#     feedback_time experiment_time    status     session  version  \
# 50     1624266137      1624266141  complete  Session 20        3
# 129    1624456709      1624456757  complete  Session 32        3
# 153    1631171920      1631171924  complete  Session 33        3
# 183    1621602733      1621602741  complete  Session 15        3
# 240    1624353567      1624353570  complete  Session 25        3
# 294    1631268553      1631268558  complete  Session 36        3
# 345    1632311134      1632311138  complete  Session 37        3
# 453       missing         missing  feedback  Session 23        3
#
#     numerical_status  language             field                 level year  \
# 50                18  Français         Chemistry  Apprenticeship (Low)  1st
# 129               18   Deutsch         Chemistry  Apprenticeship (Low)  2nd
# 153               18  Français         Chemistry  Apprenticeship (Low)  1st
# 183               18   Deutsch         Chemistry  Apprenticeship (Low)  1st
# 240               18   Deutsch  Pharma Chemistry  Apprenticeship (Low)  1st
# 294               18  Français           Biology  Apprenticeship (Low)  2nd
# 345               18  Français        Fast track  Apprenticeship (Low)  1st
# 453               16   Deutsch           Biology  Apprenticeship (Low)  2nd
#
#      consent  gender   label_q1  flag_q1_label   q2_label  flag_q2_label  \
# 50       1.0     2.0    correct            NaN    correct            1.0
# 129      1.0     1.0    correct            NaN  unrelated            1.0
# 153      1.0     1.0    correct            NaN       nans            1.0
# 183      1.0     2.0    correct            NaN    correct            1.0
# 240      1.0     1.0     larger            NaN     larger            1.0
# 294      1.0     2.0    correct            NaN     larger            1.0
# 345      1.0     2.0       same            NaN  unrelated            1.0
# 453      1.0     4.0  unrelated            1.0  unrelated            1.0
#
#     label_q3  flag_label_q3   label_q4  flag_label_q4
# 50   correct            NaN    correct            NaN
# 129  correct            NaN    correct            NaN
# 153  correct            NaN       nans            NaN
# 183   larger            NaN   to check            NaN
# 240     half            NaN  quadruple            NaN
# 294  correct            NaN    correct            NaN
# 345   larger            NaN       nans            NaN
# 453     nans            NaN       nans            NaN

# %%
q3
# Out:
#      username            start_time      exploration_time  \
# 302  xmh5qd3z  {'time': 1633935469}  {'time': 1633935598}
# 425      demo  {'time': 1634032363}  {'time': 1634032398}
#
#         ranking_task_time      ranking ranking_confidence ranking_time  \
# 302  {'time': 1633935610}         0321                 45   1633935814
# 425  {'time': 1634032629}  wrong field        wrong field   1634032636
#
#                                                     q1      q1_conf  \
# 302  L'absorbance sera deux fois plus haute que l'a...           30
# 425                                        wrong field  wrong field
#
#         q1_time                                                 q2 q2_conf  \
# 302  1633935993  elle sera se 1.59 \r\nLe liquide est plus conc...      35
# 425  1634032665                                               0.74      50
#
#         q2_time                             q3 q3_conf     q3_time  \
# 302  1633936127  la concentration sera de 8.07      30  1633936246
# 425  1634032770                       \r\n1.59      15  1634032877
#
#                                         q4 q4_conf     q4_time q5_colour0  \
# 302  l'absorbance sera de 0.8 pour ce cas       35  1633936553         90
# 425                                    0.8      30  1634033013          0
#
#     q5_colour1 q5_colour2 q5_colour3     q5_time q6_colour0 q6_colour1  \
# 302          0          0         10  1633936639         90          0
# 425          0        100          0  1634033091          0          0
#
#     q6_colour2 q6_colour3     q6_time q7_colour0 q7_colour1 q7_colour2  \
# 302          0         10  1633936702          5         60         30
# 425        100          0  1634033101          0          0          0
#
#     q7_colour3     q7_time q8_colour0 q8_colour1 q8_colour2 q8_colour3  \
# 302          5  1633936778          5          5         20         70
# 425        100  1634033115         45         45         10          0
#
#         q8_time                                            formula  \
# 302  1633936825  Le laser a plus de chemin a parcourir selon la...
# 425  1634033157  loi de lambert-beer prend en compte la longueu...
#
#     fomula_conf formula_time notes_text notes_math notes_table notes_diag  \
# 302          40   1633937090
# 425          15   1634033267
#
#      notes_time beerslaw beerslaw_conf beerslaw_time  \
# 302  1633937128      oui                  1633937137
# 425  1634033298  oui\r\n                  1634033312
#
#                                        problem_ranking problem_conf  \
# 302  [Je ne sais pas, Je ne sais pas, Co(No3)2: Cob...  wrong field
# 425   [Je ne sais pas, Je ne sais pas, Je ne sais pas]  wrong field
#
#     problem_time feedback_entertain feedback_difficult    feedback_good  \
# 302   1633937708                 55                 40                -
# 425   1634033346                 60                 10  labo virtuelle
#
#                                           feedback_bad     feedback  \
# 302  de pas pouvoir retourné sur le schéma pour rés...  wrong field
# 425                     c'est difficile de comprendre   wrong field
#
#     feedback_time experiment_time    status     session  version  \
# 302    1633937788      1633937906  complete  Session 38        4
# 425    1634033509      1634033379  complete  Session 40        4
#
#     numerical_status  language field level year  consent  gender label_q1  \
# 302               18  Français   NaN   NaN  2nd      1.0     2.0  inverse
# 425               18  Français   NaN   NaN  1st      1.0     1.0     nans
#
#      flag_q1_label q2_label  flag_q2_label   label_q3  flag_label_q3 label_q4  \
# 302            NaN  correct            NaN  unrelated            1.0  correct
# 425            NaN   larger            NaN     larger            1.0  correct
#
#      flag_label_q4
# 302            NaN
# 425            NaN

# %%
q4
# Out:
# Empty DataFrame
# Columns: [username, start_time, exploration_time, ranking_task_time, ranking, ranking_confidence, ranking_time, q1, q1_conf, q1_time, q2, q2_conf, q2_time, q3, q3_conf, q3_time, q4, q4_conf, q4_time, q5_colour0, q5_colour1, q5_colour2, q5_colour3, q5_time, q6_colour0, q6_colour1, q6_colour2, q6_colour3, q6_time, q7_colour0, q7_colour1, q7_colour2, q7_colour3, q7_time, q8_colour0, q8_colour1, q8_colour2, q8_colour3, q8_time, formula, fomula_conf, formula_time, notes_text, notes_math, notes_table, notes_diag, notes_time, beerslaw, beerslaw_conf, beerslaw_time, problem_ranking, problem_conf, problem_time, feedback_entertain, feedback_difficult, feedback_good, feedback_bad, feedback, feedback_time, experiment_time, status, session, version, numerical_status, language, field, level, year, consent, gender, label_q1, flag_q1_label, q2_label, flag_q2_label, label_q3, flag_label_q3, label_q4, flag_label_q4]
# Index: []
