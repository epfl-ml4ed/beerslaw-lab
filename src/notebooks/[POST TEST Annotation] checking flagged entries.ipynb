# %%
import os
import yaml
import pickle

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from matplotlib import pyplot as plt
import seaborn as sns

# %%
with open('../../data/post_test/some_annotated.pkl', 'rb') as fp:
    some = pickle.load(fp)

# %% [markdown]
# # Numerical Post test

# %%
q1 = some[some['label_q1'] == 'to check']
q1
# Out:
#      username            start_time      exploration_time  \
# 10   r29wzm6f  {'time': 1624976041}  {'time': 1624976055}
# 190  mkw5afyy  {'time': 1624626670}  {'time': 1624626798}
# 218  fy29cvrj  {'time': 1634033410}  {'time': 1634033454}
# 284  6cs3annc  {'time': 1624540496}  {'time': 1624540572}
#
#         ranking_task_time ranking ranking_confidence ranking_time       q1  \
# 10   {'time': 1624976976}    2130                 70   1624976990     1.59
# 190  {'time': 1624627007}    1320                 50   1624627039  2345678
# 218  {'time': 1634033463}    3120                 85   1634033543     nnnn
# 284  {'time': 1624540585}    1302                  0   1624540627       ka
#
#     q1_conf     q1_time    q2 q2_conf     q2_time                    q3  \
# 10       50  1624977018  0.96      60  1624977033                  0.96
# 190       0  1624627156   o.6       0  1624627198                  0.65
# 218      85  1634033586   222      55  1634033603  je sais toujours pas
# 284       0  1624540695    ka     100  1624540760                    ka
#
#     q3_conf     q3_time                                                 q4  \
# 10       65  1624977047                                                0.8
# 190       0  1624627229                                               0.69
# 218      60  1634033625  a = E*l*c\r\nE= a/ LC              0.6/ 0.5* 0...
# 284     100  1624540770                                                 ka
#
#     q4_conf     q4_time q5_colour0 q5_colour1 q5_colour2 q5_colour3  \
# 10       55  1624977054         20         50         20         10
# 190      20  1624627261         50         50          0          0
# 218     100  1634033913          5         45         30         20
# 284     100  1624540781         15         20         40         25
#
#         q5_time q6_colour0 q6_colour1 q6_colour2 q6_colour3     q6_time  \
# 10   1624977073         20         25         50          5  1624977096
# 190  1624627328          0          0         50         50  1624627430
# 218  1634034055          0        100          0          0  1634034089
# 284  1624540807         30         40         20         10  1624540849
#
#     q7_colour0 q7_colour1 q7_colour2 q7_colour3     q7_time q8_colour0  \
# 10     missing    missing    missing    missing     missing    missing
# 190    missing    missing    missing    missing     missing    missing
# 218          0        100          0          0  1634034101          0
# 284    missing    missing    missing    missing     missing    missing
#
#     q8_colour1 q8_colour2 q8_colour3     q8_time  \
# 10     missing    missing    missing     missing
# 190    missing    missing    missing     missing
# 218          0        100          0  1634034165
# 284    missing    missing    missing     missing
#
#                                                formula fomula_conf  \
# 10   Je breiter der Becher je höher die Extinktion ...          70
# 190                                          brrrrrrrr           0
# 218                                                NNN          45
# 284                                                 ka         100
#
#     formula_time      notes_text          notes_math notes_table notes_diag  \
# 10    1624977155  auf Notizblatt  und Taschenrechner
# 190   1624627506
# 218   1634034178
# 284   1624540865
#
#      notes_time                               beerslaw beerslaw_conf  \
# 10   1624977179                                    Ja
# 190  1624627514                                    gut
# 218  1634034191                                    OUI
# 284  1624540892  null, gar nicht, was soll der scheiss
#
#     beerslaw_time                                    problem_ranking  \
# 10     1624977186  [Ich weiss nicht, Ich weiss nicht, Ich weiss n...
# 190    1624627534  [Co(No3)2: Cobalt (II) nitrate, CoCl2: Cobalt ...
# 218    1634034201  [Co(No3)2: Cobalt (II) nitrate, K2CrO4: Potass...
# 284    1624540908  [Drink mix, NiCl2: Nickel (II) chromate, Co(No...
#
#     problem_conf problem_time feedback_entertain feedback_difficult  \
# 10   wrong field   1624978054                 40                 70
# 190  wrong field   1624627857                 60                 30
# 218  wrong field   1634034265                  0                100
# 284  wrong field   1624540929                  0                100
#
#                                feedback_good  \
# 10   Die zum selbst-ausprobierende Grafiken.
# 190                             interagieren
# 218                               c'est joli
# 284                                   nichts
#
#                                           feedback_bad     feedback  \
# 10   Zu viele Fragen in Aufgabe 1 zu den Extinktion...  wrong field
# 190  wenn weiter gedrückt wurde konnte man nicht me...  wrong field
# 218  on ne comprend pas le sens de l'exercice avant...  wrong field
# 284  alles, was soll der scheiss?? WAS WOLLEN SIE D...  wrong field
#
#     feedback_time experiment_time    status     session  version  \
# 10     1624978149      1624978242  complete  Session 29        3
# 190    1624627949      1624627952  complete  Session 23        3
# 218    1634034396      1634034399  complete  Session 40        4
# 284    1624541042      1624541045  complete  Session 31        3
#
#     numerical_status  language      field                 level year  consent  \
# 10                18   Deutsch  Chemistry  Apprenticeship (Low)  2nd      1.0
# 190               18   Deutsch    Biology  Apprenticeship (Low)  2nd      1.0
# 218               18  Français        NaN                   NaN  1st      1.0
# 284               18   Deutsch  Chemistry  Apprenticeship (Low)  1st      1.0
#
#      gender  label_q1  flag_q1_label q2_label  flag_q2_label   label_q3  \
# 10      2.0  to check            NaN   larger            NaN    correct
# 190     1.0  to check            NaN   larger            NaN    smaller
# 218     3.0  to check            NaN   larger            NaN       nans
# 284     3.0  to check            NaN     nans            NaN  unrelated
#
#      flag_label_q3   label_q4  flag_label_q4
# 10             NaN    correct            NaN
# 190            NaN     larger            NaN
# 218            NaN    smaller            NaN
# 284            NaN  unrelated            NaN

# %%
q1.iloc[3]['feedback_bad']
# Out:
# 'alles, was soll der scheiss?? WAS WOLLEN SIE DAMIT ERREICHEN????'

# %%
q2 = some[some['q2_label'] == 'to check']
q2
# Out:
# Empty DataFrame
# Columns: [username, start_time, exploration_time, ranking_task_time, ranking, ranking_confidence, ranking_time, q1, q1_conf, q1_time, q2, q2_conf, q2_time, q3, q3_conf, q3_time, q4, q4_conf, q4_time, q5_colour0, q5_colour1, q5_colour2, q5_colour3, q5_time, q6_colour0, q6_colour1, q6_colour2, q6_colour3, q6_time, q7_colour0, q7_colour1, q7_colour2, q7_colour3, q7_time, q8_colour0, q8_colour1, q8_colour2, q8_colour3, q8_time, formula, fomula_conf, formula_time, notes_text, notes_math, notes_table, notes_diag, notes_time, beerslaw, beerslaw_conf, beerslaw_time, problem_ranking, problem_conf, problem_time, feedback_entertain, feedback_difficult, feedback_good, feedback_bad, feedback, feedback_time, experiment_time, status, session, version, numerical_status, language, field, level, year, consent, gender, label_q1, flag_q1_label, q2_label, flag_q2_label, label_q3, flag_label_q3, label_q4, flag_label_q4]
# Index: []

# %%
q3 = some[some['label_q3'] == 'to check']
q3
# Out:
# Empty DataFrame
# Columns: [username, start_time, exploration_time, ranking_task_time, ranking, ranking_confidence, ranking_time, q1, q1_conf, q1_time, q2, q2_conf, q2_time, q3, q3_conf, q3_time, q4, q4_conf, q4_time, q5_colour0, q5_colour1, q5_colour2, q5_colour3, q5_time, q6_colour0, q6_colour1, q6_colour2, q6_colour3, q6_time, q7_colour0, q7_colour1, q7_colour2, q7_colour3, q7_time, q8_colour0, q8_colour1, q8_colour2, q8_colour3, q8_time, formula, fomula_conf, formula_time, notes_text, notes_math, notes_table, notes_diag, notes_time, beerslaw, beerslaw_conf, beerslaw_time, problem_ranking, problem_conf, problem_time, feedback_entertain, feedback_difficult, feedback_good, feedback_bad, feedback, feedback_time, experiment_time, status, session, version, numerical_status, language, field, level, year, consent, gender, label_q1, flag_q1_label, q2_label, flag_q2_label, label_q3, flag_label_q3, label_q4, flag_label_q4]
# Index: []

# %%
q4 = some[some['label_q4'] == 'to check']
q4
# Out:
#      username            start_time      exploration_time  \
# 183  bebyve9b  {'time': 1621600645}  {'time': 1621600869}
# 335  bje92qp8  {'time': 1632309858}  {'time': 1632309891}
#
#         ranking_task_time ranking ranking_confidence ranking_time       q1  \
# 183  {'time': 1621601960}    0231                 50   1621601987  0.37 nm
# 335  {'time': 1632309908}    0213                 40   1632310043   0.74/2
#
#     q1_conf     q1_time         q2 q2_conf     q2_time                q3  \
# 183      40  1621602100    1.59 nm      40  1621602177           1.44 nm
# 335      45  1632310129  1*433*300      10  1632310272  780*0.5*200= Abs
#
#     q3_conf     q3_time                                     q4 q4_conf  \
# 183      25  1621602251                                    abc      35
# 335      10  1632310347  0.60/0.5*600*544=x\r\nx*2*544*200=Abs       5
#
#         q4_time q5_colour0 q5_colour1 q5_colour2 q5_colour3     q5_time  \
# 183  1621602414         10         90          0          0  1621602464
# 335  1632310456          0          0         50         50  1632310515
#
#     q6_colour0 q6_colour1 q6_colour2 q6_colour3     q6_time q7_colour0  \
# 183          0          0          0        100  1621602476    missing
# 335          0          0         25         75  1632310594    missing
#
#     q7_colour1 q7_colour2 q7_colour3  q7_time q8_colour0 q8_colour1  \
# 183    missing    missing    missing  missing    missing    missing
# 335    missing    missing    missing  missing    missing    missing
#
#     q8_colour2 q8_colour3  q8_time  \
# 183    missing    missing  missing
# 335    missing    missing  missing
#
#                                                formula fomula_conf  \
# 183                                          mvrorjgjg          30
# 335  Abs= Concentration*la largeur du bécher*la lon...          30
#
#     formula_time notes_text notes_math notes_table notes_diag  notes_time  \
# 183   1621602490     fkfkfg                                    1621602506
# 335   1632310869                                               1632310897
#
#                                               beerslaw beerslaw_conf  \
# 183                                          ein Wenig
# 335  On en avait parlé en cours mais je m'en souven...
#
#     beerslaw_time                                    problem_ranking  \
# 183    1621602524  [K2CrO4: Potassium chromate, KMnO4: Potassium ...
# 335    1632310928  [Co(No3)2: Cobalt (II) nitrate, CoCl2: Cobalt ...
#
#     problem_conf problem_time feedback_entertain feedback_difficult  \
# 183  wrong field   1621602588                 60                 50
# 335  wrong field   1632311594                 70                 40
#
#                                          feedback_good  \
# 183  Die spielerische Herangehensweise und die Mögl...
# 335                                      L'activité 3
#
#                                           feedback_bad     feedback  \
# 183  Zeit zu kurz bemessen um sich wirklich mit der...  wrong field
# 335                                 C'est très poussé.  wrong field
#
#     feedback_time experiment_time    status     session  version  \
# 183    1621602733      1621602741  complete  Session 15        3
# 335    1632311782      1632312015  complete  Session 37        3
#
#     numerical_status  language       field                 level year  \
# 183               18   Deutsch   Chemistry  Apprenticeship (Low)  1st
# 335               18  Français  Fast track  Apprenticeship (Low)  1st
#
#      consent  gender label_q1  flag_q1_label q2_label  flag_q2_label label_q3  \
# 183      1.0     2.0  correct            NaN  correct            1.0   larger
# 335      1.0     2.0  correct            NaN   larger            NaN   larger
#
#      flag_label_q3  label_q4  flag_label_q4
# 183            NaN  to check            NaN
# 335            NaN  to check            NaN
