# %% [markdown]
# In this notebook, we take the extracted post test information, and we clean it such that: \
#     - DVET entries are cleaned out \
#     - missing rankings are taken away

# %%
import os 
import re
import pickle

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
with open('../../data/post_test/extracted.pkl', 'rb') as fp:
    pt = pickle.load(fp)
    pt['ranking'] = pt['ranking'].fillna('missing')

# %%
temp = pt[pt['ranking'] != 'missing']
temp = temp[temp['ranking'] != 'uncomplete']
temp = temp[temp['ranking'] != '']

# %%
temp
# Out:
#      username            start_time      exploration_time  \
# 34   wvxkvhne  {'time': 1620736751}  {'time': 1620737223}
# 101  p44vw7td  {'time': 1620717808}  {'time': 1620717997}
# 104  z5dzzgk5  {'time': 1620717861}  {'time': 1620718027}
# 108  baqyfz2h  {'time': 1620717781}  {'time': 1620717805}
# 138  5y535ct3  {'time': 1620132639}  {'time': 1620132852}
# ..        ...                   ...                   ...
# 464  ky8kttpv  {'time': 1620375958}  {'time': 1620376249}
# 465  9bp6yz7m  {'time': 1620375936}  {'time': 1620376155}
# 466  ke6msbfr  {'time': 1620375949}  {'time': 1620376384}
# 467  fj5tdybn  {'time': 1620376155}  {'time': 1620376211}
# 468  t6rjyw6s  {'time': 1620376288}  {'time': 1620376436}
#
#              ranking_time ranking ranking_confidence ranking_time  \
# 34   {'time': 1620737445}    3012                 -1   1620737625
# 101  {'time': 1620718488}    0231                 -1   1620718520
# 104  {'time': 1620718056}    3210                 -1   1620718115
# ...

# %% [markdown]
# # Clean

# %%
print('length of the dataframe: {}, unique usernames: {}'.format(len(post), len(post['username'].unique())))
# Out:
# length of the dataframe: 469, unique usernames: 469

# %%
# list of usernames that should be excluded
status_rejected = [
    "'name'", "'1'"
]

rejected = post[post['status'].isin(status_rejected)]
usernames_rejected = list(rejected['username'])

# %%
# remove non started entries
print('Original length of the dataframe: {}'.format(len(post)))
post = post[post['status'] != "'name'"]

# remove test entries 
post = post[post['status'] != "'1'"] # only usernames
post = post[post['status'] != "'2'"] # only usernames
post = post[post['status'] != "'3'"] # only usernames
post = post[(post['status'] != "'5'") | (post['ranking'] != 'missing')] # No rankings

# separating between those with rankings and those without the ranking
rankings = post[(post['status'] == "'5'") & (post['ranking'] != 'missing')]

rankings = rankings.append(post[(post['status'] == "'6'") & (post['ranking'] != 'missing')])
questions = post[(post['status'] == "'6'") & (post['ranking'] == 'missing')]

rankings = rankings.append(post[(post['status'] == "'8'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'8'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'9'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'9'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'10'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'10'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'11'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'11'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'12'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'12'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'15'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'15'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'17'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'17'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'choices'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'choices'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'feedback'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'feedback'") & (post['ranking'] == 'missing')])

rankings = rankings.append(post[(post['status'] == "'complete'") & (post['ranking'] != 'missing')])
questions = questions.append(post[(post['status'] == "'complete'") & (post['ranking'] == 'missing')])
# Out:
# Original length of the dataframe: 469

# %%
len(rankings)
# Out:
# 71

# %%
post[post['ranking'] != 'missing']
# Out:
#      username            start_time      exploration_time  \
# 1    y8qbtkmf  {'time': 1624975991}  {'time': 1624976130}
# 2    sr34qyfx  {'time': 1624975979}  {'time': 1624976049}
# 3    ntqpqkpq  {'time': 1624976038}  {'time': 1624976175}
# 4    r29wzm6f  {'time': 1624976041}  {'time': 1624976055}
# 5    zgs84jfy  {'time': 1624976057}  {'time': 1624976078}
# ..        ...                   ...                   ...
# 464  ky8kttpv  {'time': 1620375958}  {'time': 1620376249}
# 465  9bp6yz7m  {'time': 1620375936}  {'time': 1620376155}
# 466  ke6msbfr  {'time': 1620375949}  {'time': 1620376384}
# 467  fj5tdybn  {'time': 1620376155}  {'time': 1620376211}
# 468  t6rjyw6s  {'time': 1620376288}  {'time': 1620376436}
#
#              ranking_time ranking ranking_confidence ranking_time.1  \
# 1    {'time': 1624976138}     NaN                100     1624976297
# 2    {'time': 1624976060}     NaN                 50     1624976281
# ...
