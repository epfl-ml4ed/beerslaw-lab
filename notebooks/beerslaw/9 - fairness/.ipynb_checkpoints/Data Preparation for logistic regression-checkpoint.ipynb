# %% [markdown]
# <h3 style="color:royalblue"> This notebook's purpose is to prepare the data for the logistic regression to be conducted in R.</h3>

# %%
cd ../../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %%
import os
import re
import dill
import pickle

import pandas as pd 

from extractors.sequencer.flat.simplemorestates_secondsflat import SimpleMoreStateSecondsFlat
from extractors.pipeline_maker import PipelineMaker

# %% [markdown]
# # Make the sequences

# %%
settings = {
    'data': {
        'pipeline': {
            'sequencer_dragasclick': True,
            'break_threshold': 0.6
        }
    }
}

# %%
# Where to find the simulation objects
parsed_simulation_path = '../data/beerslaw/parsed simulations/'
files = os.listdir(parsed_simulation_path)
files = [f for f in files if 'simulation' in f]
files = [f for f in files if '_t2v_' in f]

# Load demographics information
with open('../data/beerslaw/post_test/rankings.pkl', 'rb') as fp:
    ranks = pickle.load(fp)
    ranks = ranks.set_index('username')

# useful regex
id_regex = re.compile('lid([^_]+)_')

# %%
# Load sequencer
sequencer = SimpleMoreStateSecondsFlat(settings)
sequencer.set_rankings(ranks)

# %%
# Parse
id_dictionary = {'index':{}, 'sequences': {}}
i = 0
while len(files) != 0:
    file = files[0]
    lid = id_regex.findall(file)[0]
    print(file)
    print('   {}'.format(lid))
    
    
    # Retrieve demographics
    try:
        permutation = ranks.loc[lid]['ranking']
        gender = ranks.loc[lid]['gender']
        year = ranks.loc[lid]['year']
        field = ranks.loc[lid]['field']
        language = ranks.loc[lid]['language']
        print('    ranking: {}, gender: {}, year: {}, field: {}, language: {}'.format(
            permutation, gender, year, field, language
        ))
    except KeyError:
        print('    No ranking or demographics')
        files_noranking = []
        files_noranking.append('permmissing_lid' + str(lid) + '_t1v_simulation.pkl')
        files_noranking.append('permmissing_lid' + str(lid) + '_t2v_simulation.pkl')
        files_noranking.append('permmissing_lid' + str(lid) + '_t3v_simulation.pkl')
        files_noranking.append('permwrong field_lid' + str(lid) + '_t1v_simulation.pkl')
        files_noranking.append('permwrong field_lid' + str(lid) + '_t2v_simulation.pkl')
        files_noranking.append('permwrong field_lid' + str(lid) + '_t3v_simulation.pkl')
        for f in files_noranking:
            if f in files:
                files.remove(f)
                print(f)
        continue
        
    
    # Retrieve actions    
    file_path = 'perm{}_lid{}_t2v_simulation.pkl'.format(permutation, lid)
    try:
        with open(parsed_simulation_path + file_path, 'rb') as fp:
            sim = dill.load(fp)
            sim.set_permutation(permutation)
            sim.save()
        if file_path in files:
            files.remove(file_path)
        file_path1 = 'perm{}_lid{}_t1v_simulation.pkl'.format(permutation, lid)
        if file_path1 in files:
            files.remove(file_path1)
        file_path3 = 'perm{}_lid{}_t3v_simulation.pkl'.format(permutation, lid)
        if file_path3 in files:
            files.remove(file_path3)
        labels, begins, ends = sequencer.get_sequences(sim, lid)
        last_timestamp = sim.get_last_timestamp()
    except FileNotFoundError:
        labels, begins, ends = [], [], []
        last_timestamp = 0
    except TypeError:
        labels, begins, ends = [], [], []
        last_timestamp = 0

    sim_dict = {
        'sequence': labels,
        'begin': begins,
        'end': ends,
        'permutation': permutation,
        'last_timestamp': last_timestamp,
        'learner_id': str(lid),
        'gender': gender,
        'year': year,
        'field': field,
        'language': language
    }
    path = '../data/beerslaw/logistic_regression/sequenced/simplemorestates_secondsflat/p{}_lid{}_t2_sequenced.pkl'.format(
        permutation, lid,
    )
    with open(path, 'wb') as fp:
        pickle.dump(sim_dict, fp)

    id_dictionary['sequences'][i] = {
        'path': path,
        'length': len(labels),
        'learner_id': str(lid),
        'gender': gender,
        'year': year,
        'field': field,
        'language': language
    }
    id_dictionary['index'][str(lid)] = i
    i += 1
    
with open('../data/beerslaw/logistic_regression/sequenced/simplemorestates_secondsflat/id_dictionary.pkl', 'wb') as fp:
    pickle.dump(id_dictionary, fp)
# Out:
# perm2013_lidsvdphyjs_t2v_simulation.pkl
#    svdphyjs
#     ranking: 2013, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2103_lidwyj76ntd_t2v_simulation.pkl
#    wyj76ntd
#     ranking: 2103, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3210_lidnmptx7nj_t2v_simulation.pkl
#    nmptx7nj
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3120_lidgc663sap_t2v_simulation.pkl
#    gc663sap
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm0213_lid8nh4zvcp_t2v_simulation.pkl
#    8nh4zvcp
#     ranking: 0213, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidn3977erj_t2v_simulation.pkl
#    n3977erj
#     ranking: 3012, gender: 2, year: 1st, field: Fast track, language: Français
# perm3210_liduad7cmhv_t2v_simulation.pkl
#    uad7cmhv
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidrwu8yjw9_t2v_simulation.pkl
#    rwu8yjw9
#     No ranking or demographics
# permmissing_lidrwu8yjw9_t2v_simulation.pkl
# perm2031_lidnemddmx6_t2v_simulation.pkl
#    nemddmx6
#     ranking: 2031, gender: 2, year: 1st, field: Biology, language: Français
# perm0312_lidzbabnwym_t2v_simulation.pkl
#    zbabnwym
#     ranking: 0312, gender: 2, year: 1st, field: Biology, language: Français
# perm3021_lid5f4q4ng5_t2v_simulation.pkl
#    5f4q4ng5
#     ranking: 3021, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidwbvxv9ju_t2v_simulation.pkl
#    wbvxv9ju
#     No ranking or demographics
# permmissing_lidwbvxv9ju_t2v_simulation.pkl
# perm3012_lidujpk3gf4_t2v_simulation.pkl
#    ujpk3gf4
#     ranking: 3012, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lid7hrf6cdu_t2v_simulation.pkl
#    7hrf6cdu
#     ranking: 3012, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3120_lidb8g49nvw_t2v_simulation.pkl
#    b8g49nvw
#     ranking: 3120, gender: 4, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lid5zrt4f8z_t2v_simulation.pkl
#    5zrt4f8z
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidu2ntt4wv_t2v_simulation.pkl
#    u2ntt4wv
#     No ranking or demographics
# permmissing_lidu2ntt4wv_t2v_simulation.pkl
# permmissing_lid7ywsk96r_t2v_simulation.pkl
#    7ywsk96r
#     No ranking or demographics
# permmissing_lid7ywsk96r_t2v_simulation.pkl
# perm3012_lidkq2e6dgu_t2v_simulation.pkl
#    kq2e6dgu
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidbm89te3c_t2v_simulation.pkl
#    bm89te3c
#     No ranking or demographics
# permmissing_lidbm89te3c_t2v_simulation.pkl
# perm3012_lidwwj8nq34_t2v_simulation.pkl
#    wwj8nq34
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Français
# permmissing_lidvvtfq98r_t2v_simulation.pkl
#    vvtfq98r
#     No ranking or demographics
# permmissing_lidvvtfq98r_t2v_simulation.pkl
# perm3012_lid7ygreyfc_t2v_simulation.pkl
#    7ygreyfc
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2130_lidqqf6nsga_t2v_simulation.pkl
#    qqf6nsga
#     ranking: 2130, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2310_lidxvsgn53d_t2v_simulation.pkl
#    xvsgn53d
#     ranking: 2310, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm0312_lidqsd9cb5e_t2v_simulation.pkl
#    qsd9cb5e
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# permmissing_lidakzsmgnj_t2v_simulation.pkl
#    akzsmgnj
#     No ranking or demographics
# permmissing_lidakzsmgnj_t2v_simulation.pkl
# perm3210_lidcp7mfn24_t2v_simulation.pkl
#    cp7mfn24
#     ranking: 3210, gender: 3, year: 3rd, field: Chemistry, language: Deutsch
# perm3120_lidj9qgkaej_t2v_simulation.pkl
#    j9qgkaej
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm0312_lid85pdk9mq_t2v_simulation.pkl
#    85pdk9mq
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2301_lidrfand3tt_t2v_simulation.pkl
#    rfand3tt
#     ranking: 2301, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lidpuzxz678_t2v_simulation.pkl
#    puzxz678
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Français
# perm2310_lidk7p5eryf_t2v_simulation.pkl
#    k7p5eryf
#     ranking: 2310, gender: 4, year: 2nd, field: Biology, language: Deutsch
# perm2103_lidwktpsvp8_t2v_simulation.pkl
#    wktpsvp8
#     ranking: 2103, gender: 1, year: 1st, field: Chemistry, language: Français
# perm2031_lidmnhmyuhb_t2v_simulation.pkl
#    mnhmyuhb
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm0213_lidtsrnkj8w_t2v_simulation.pkl
#    tsrnkj8w
#     ranking: 0213, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3012_lid5xuzjwdp_t2v_simulation.pkl
#    5xuzjwdp
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3021_lidfavvtnnf_t2v_simulation.pkl
#    favvtnnf
#     ranking: 3021, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lidkcv4kfm2_t2v_simulation.pkl
#    kcv4kfm2
#     No ranking or demographics
# permmissing_lidkcv4kfm2_t2v_simulation.pkl
# perm3012_lidc87kgzbr_t2v_simulation.pkl
#    c87kgzbr
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3102_lidjamrhf3h_t2v_simulation.pkl
#    jamrhf3h
#     ranking: 3102, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lidfh76v5qx_t2v_simulation.pkl
#    fh76v5qx
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2031_lidt6rjyw6s_t2v_simulation.pkl
#    t6rjyw6s
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm0321_lidvhsgf3xa_t2v_simulation.pkl
#    vhsgf3xa
#     ranking: 0321, gender: 4, year: 2nd, field: Biology, language: Français
# perm2031_lid5h9umyr6_t2v_simulation.pkl
#    5h9umyr6
#     ranking: 2031, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lids9prcjfd_t2v_simulation.pkl
#    s9prcjfd
#     ranking: 3012, gender: 3, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0213_lidmhek2323_t2v_simulation.pkl
#    mhek2323
#     ranking: 0213, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm1320_lid33asfz2u_t2v_simulation.pkl
#    33asfz2u
#     ranking: 1320, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidcaq55qe8_t2v_simulation.pkl
#    caq55qe8
#     ranking: 3012, gender: 2, year: 2nd, field: Biology, language: Français
# perm2130_liddrccqhk4_t2v_simulation.pkl
#    drccqhk4
#     ranking: 2130, gender: 1, year: 1st, field: Biology, language: Français
# permmissing_lidrqpdjumr_t2v_simulation.pkl
#    rqpdjumr
#     No ranking or demographics
# permmissing_lidrqpdjumr_t2v_simulation.pkl
# perm0312_lidtzbaaz7e_t2v_simulation.pkl
#    tzbaaz7e
#     ranking: 0312, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm1032_lidur9sxzx7_t2v_simulation.pkl
#    ur9sxzx7
#     ranking: 1032, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3012_lidxe7c36dk_t2v_simulation.pkl
#    xe7c36dk
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3120_lidjx3yyy26_t2v_simulation.pkl
#    jx3yyy26
#     ranking: 3120, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lidqbf3sp76_t2v_simulation.pkl
#    qbf3sp76
#     No ranking or demographics
# permmissing_lidqbf3sp76_t2v_simulation.pkl
# perm2031_lidknbr3qun_t2v_simulation.pkl
#    knbr3qun
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lideefp7dh9_t2v_simulation.pkl
#    eefp7dh9
#     No ranking or demographics
# permmissing_lideefp7dh9_t2v_simulation.pkl
# perm3120_lidupp6pqmx_t2v_simulation.pkl
#    upp6pqmx
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidbebyve9b_t2v_simulation.pkl
#    bebyve9b
#     ranking: 0231, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm0321_lid9p4h3zdx_t2v_simulation.pkl
#    9p4h3zdx
#     ranking: 0321, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm2031_liduswb2jez_t2v_simulation.pkl
#    uswb2jez
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lidr8n3bcnu_t2v_simulation.pkl
#    r8n3bcnu
#     No ranking or demographics
# permmissing_lidr8n3bcnu_t2v_simulation.pkl
# perm3012_lidva43652k_t2v_simulation.pkl
#    va43652k
#     ranking: 3012, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm1203_lidupkt7qb4_t2v_simulation.pkl
#    upkt7qb4
#     ranking: 1203, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3120_lidwpszzhxa_t2v_simulation.pkl
#    wpszzhxa
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2103_lidcrak75dx_t2v_simulation.pkl
#    crak75dx
#     ranking: 2103, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm3012_lidaddf7f7d_t2v_simulation.pkl
#    addf7f7d
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidx6e99ywy_t2v_simulation.pkl
#    x6e99ywy
#     No ranking or demographics
# permmissing_lidx6e99ywy_t2v_simulation.pkl
# perm2301_lid84nmc3df_t2v_simulation.pkl
#    84nmc3df
#     ranking: 2301, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidtf97geej_t2v_simulation.pkl
#    tf97geej
#     No ranking or demographics
# permmissing_lidtf97geej_t2v_simulation.pkl
# perm3210_lidurwu33jd_t2v_simulation.pkl
#    urwu33jd
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Français
# perm2031_lid4k4kc2k6_t2v_simulation.pkl
#    4k4kc2k6
#     ranking: 2031, gender: 1, year: 2nd, field: Biology, language: Deutsch
# permmissing_lid6z8t3mxa_t2v_simulation.pkl
#    6z8t3mxa
#     No ranking or demographics
# permmissing_lid6z8t3mxa_t2v_simulation.pkl
# perm3012_lid3xcaamq9_t2v_simulation.pkl
#    3xcaamq9
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lido9ffsiwt_t2v_simulation.pkl
#    o9ffsiwt
#     ranking: 0312, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm3021_lid6j6u2yct_t2v_simulation.pkl
#    6j6u2yct
#     ranking: 3021, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm0321_lidbqmcqxyx_t2v_simulation.pkl
#    bqmcqxyx
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Français
# permmissing_lid7sfwehhm_t2v_simulation.pkl
#    7sfwehhm
#     No ranking or demographics
# permmissing_lid7sfwehhm_t2v_simulation.pkl
# permmissing_lid39ggtzcu_t2v_simulation.pkl
#    39ggtzcu
#     No ranking or demographics
# permmissing_lid39ggtzcu_t2v_simulation.pkl
# perm3012_lid5vvwhzqs_t2v_simulation.pkl
#    5vvwhzqs
#     ranking: 3012, gender: 3, year: 1st, field: Chemistry, language: Deutsch
# perm3120_lidecaf72fu_t2v_simulation.pkl
#    ecaf72fu
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm0312_lidsgsxmkfm_t2v_simulation.pkl
#    sgsxmkfm
#     ranking: 0312, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm0123_lidbezdgyya_t2v_simulation.pkl
#    bezdgyya
#     ranking: 0123, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2013_lid6z7nfy2j_t2v_simulation.pkl
#    6z7nfy2j
#     ranking: 2013, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3102_lideb9iv6v2_t2v_simulation.pkl
#    eb9iv6v2
#     ranking: 3102, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidy9tk3ysm_t2v_simulation.pkl
#    y9tk3ysm
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lidpt2nbb4w_t2v_simulation.pkl
#    pt2nbb4w
#     No ranking or demographics
# permmissing_lidpt2nbb4w_t2v_simulation.pkl
# perm2130_lida57jkjgv_t2v_simulation.pkl
#    a57jkjgv
#     ranking: 2130, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# permmissing_lidf5wa2gzf_t2v_simulation.pkl
#    f5wa2gzf
#     No ranking or demographics
# permmissing_lidf5wa2gzf_t2v_simulation.pkl
# perm2103_lid3w54b2bu_t2v_simulation.pkl
#    3w54b2bu
#     ranking: 2103, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lidtbdn5up8_t2v_simulation.pkl
#    tbdn5up8
#     No ranking or demographics
# permmissing_lidtbdn5up8_t2v_simulation.pkl
# perm2130_lidw9w2hw35_t2v_simulation.pkl
#    w9w2hw35
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm1203_liddubyutqd_t2v_simulation.pkl
#    dubyutqd
#     ranking: 1203, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lid2dfxa5he_t2v_simulation.pkl
#    2dfxa5he
#     No ranking or demographics
# permmissing_lid2dfxa5he_t2v_simulation.pkl
# permmissing_lidsqrqdsge_t2v_simulation.pkl
#    sqrqdsge
#     No ranking or demographics
# permmissing_lidsqrqdsge_t2v_simulation.pkl
# perm3120_lid3st3y5gc_t2v_simulation.pkl
#    3st3y5gc
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lid2xjmtbvz_t2v_simulation.pkl
#    2xjmtbvz
#     ranking: 2031, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm3012_lidj9ukgkp5_t2v_simulation.pkl
#    j9ukgkp5
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2103_lidrg4fgfyh_t2v_simulation.pkl
#    rg4fgfyh
#     ranking: 2103, gender: 2, year: 1st, field: Biology, language: Français
# perm0312_lidbf4iuomx_t2v_simulation.pkl
#    bf4iuomx
#     ranking: 0312, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2301_lid9aagpn4d_t2v_simulation.pkl
#    9aagpn4d
#     ranking: 2301, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm0132_lidcjarhqn9_t2v_simulation.pkl
#    cjarhqn9
#     ranking: 0132, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lidujp9fgpn_t2v_simulation.pkl
#    ujp9fgpn
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm0231_lidevqzjs5p_t2v_simulation.pkl
#    evqzjs5p
#     ranking: 0231, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidsmqjhu44_t2v_simulation.pkl
#    smqjhu44
#     ranking: 0231, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3102_lidfyf6ag5v_t2v_simulation.pkl
#    fyf6ag5v
#     ranking: 3102, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2103_lidh543nsc8_t2v_simulation.pkl
#    h543nsc8
#     ranking: 2103, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0213_lidhg7zc2sv_t2v_simulation.pkl
#    hg7zc2sv
#     ranking: 0213, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lid786zpupn_t2v_simulation.pkl
#    786zpupn
#     No ranking or demographics
# permmissing_lid786zpupn_t2v_simulation.pkl
# perm2130_lidkq4eymtu_t2v_simulation.pkl
#    kq4eymtu
#     ranking: 2130, gender: 2, year: 1st, field: Fast track, language: Français
# perm0123_lidr2q9q35x_t2v_simulation.pkl
#    r2q9q35x
#     ranking: 0123, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3120_lid4rhnvke9_t2v_simulation.pkl
#    4rhnvke9
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3021_lidnpatrq7r_t2v_simulation.pkl
#    npatrq7r
#     ranking: 3021, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2013_lidcdq4drkk_t2v_simulation.pkl
#    cdq4drkk
#     ranking: 2013, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm0231_lidmzjq6z9t_t2v_simulation.pkl
#    mzjq6z9t
#     ranking: 0231, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidwef64erj_t2v_simulation.pkl
#    wef64erj
#     No ranking or demographics
# permmissing_lidwef64erj_t2v_simulation.pkl
# permmissing_lidhabxmccr_t2v_simulation.pkl
#    habxmccr
#     No ranking or demographics
# permmissing_lidhabxmccr_t2v_simulation.pkl
# permmissing_lidsbjxmaqm_t2v_simulation.pkl
#    sbjxmaqm
#     No ranking or demographics
# permmissing_lidsbjxmaqm_t2v_simulation.pkl
# perm0123_lidmp2aa258_t2v_simulation.pkl
#    mp2aa258
#     ranking: 0123, gender: 2, year: 1st, field: Fast track, language: Français
# perm0213_lidphupma28_t2v_simulation.pkl
#    phupma28
#     ranking: 0213, gender: 2, year: 1st, field: Fast track, language: Français
# perm3012_lidsctj44cs_t2v_simulation.pkl
#    sctj44cs
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm1032_lidxau6wapw_t2v_simulation.pkl
#    xau6wapw
#     ranking: 1032, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3021_lidunkrat9w_t2v_simulation.pkl
#    unkrat9w
#     ranking: 3021, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0231_lide22ppyf7_t2v_simulation.pkl
#    e22ppyf7
#     ranking: 0231, gender: 4, year: 1st, field: Chemistry, language: Français
# perm0213_lidxsxkdf7k_t2v_simulation.pkl
#    xsxkdf7k
#     ranking: 0213, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3012_lidpesfpzbv_t2v_simulation.pkl
#    pesfpzbv
#     ranking: 3012, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm1320_lidyc3vmnuf_t2v_simulation.pkl
#    yc3vmnuf
#     ranking: 1320, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm1230_lidx3ykresy_t2v_simulation.pkl
#    x3ykresy
#     ranking: 1230, gender: 2, year: 1st, field: Fast track, language: Français
# permmissing_lid9x24tp6b_t2v_simulation.pkl
#    9x24tp6b
#     No ranking or demographics
# permmissing_lid9x24tp6b_t2v_simulation.pkl
# permmissing_lidw6az39g6_t2v_simulation.pkl
#    w6az39g6
#     No ranking or demographics
# permmissing_lidw6az39g6_t2v_simulation.pkl
# perm3012_lidxdxyjh8j_t2v_simulation.pkl
#    xdxyjh8j
#     ranking: 3012, gender: 3, year: 1st, field: Biology, language: Français
# perm3120_lidmwfdr4ys_t2v_simulation.pkl
#    mwfdr4ys
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2301_liddnvedphf_t2v_simulation.pkl
#    dnvedphf
#     ranking: 2301, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lid6tg95rzr_t2v_simulation.pkl
#    6tg95rzr
#     ranking: 0231, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm0231_lidfj5tdybn_t2v_simulation.pkl
#    fj5tdybn
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3021_lid7xhcecye_t2v_simulation.pkl
#    7xhcecye
#     ranking: 3021, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3120_lidxj86wyup_t2v_simulation.pkl
#    xj86wyup
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3210_lidwguewwkp_t2v_simulation.pkl
#    wguewwkp
#     ranking: 3210, gender: 1, year: 1st, field: Fast track, language: Français
# perm0231_lidtsvcrpeg_t2v_simulation.pkl
#    tsvcrpeg
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lids43ut7tg_t2v_simulation.pkl
#    s43ut7tg
#     No ranking or demographics
# permmissing_lids43ut7tg_t2v_simulation.pkl
# perm1023_lidh9t9mxtx_t2v_simulation.pkl
#    h9t9mxtx
#     ranking: 1023, gender: 2, year: 2nd, field: Biology, language: Français
# perm1320_lidht865nws_t2v_simulation.pkl
#    ht865nws
#     ranking: 1320, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm1032_lid552gbupp_t2v_simulation.pkl
#    552gbupp
#     ranking: 1032, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0312_lidpadezf8m_t2v_simulation.pkl
#    padezf8m
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidnyyfpabq_t2v_simulation.pkl
#    nyyfpabq
#     No ranking or demographics
# permmissing_lidnyyfpabq_t2v_simulation.pkl
# perm0231_lidsgdgynxy_t2v_simulation.pkl
#    sgdgynxy
#     ranking: 0231, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# permmissing_lide2825x2d_t2v_simulation.pkl
#    e2825x2d
#     No ranking or demographics
# permmissing_lide2825x2d_t2v_simulation.pkl
# perm3012_lidv5wcy2tt_t2v_simulation.pkl
#    v5wcy2tt
#     ranking: 3012, gender: 2, year: 1st, field: Fast track, language: Français
# perm0321_lidsuyrrcqe_t2v_simulation.pkl
#    suyrrcqe
#     ranking: 0321, gender: 4, year: 3rd, field: Chemistry, language: Deutsch
# perm0213_lid4bu2rkv3_t2v_simulation.pkl
#    4bu2rkv3
#     ranking: 0213, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm2031_lidamqnxthw_t2v_simulation.pkl
#    amqnxthw
#     ranking: 2031, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm3210_lidz6ur4njh_t2v_simulation.pkl
#    z6ur4njh
#     ranking: 3210, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm2130_lidac4q67z9_t2v_simulation.pkl
#    ac4q67z9
#     ranking: 2130, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3210_lid2crhmbq7_t2v_simulation.pkl
#    2crhmbq7
#     ranking: 3210, gender: 2, year: 1st, field: Chemistry, language: Français
# perm0213_liddbt5na3s_t2v_simulation.pkl
#    dbt5na3s
#     ranking: 0213, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm1032_lidgvqh7qr2_t2v_simulation.pkl
#    gvqh7qr2
#     ranking: 1032, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm2013_lidwger3sfa_t2v_simulation.pkl
#    wger3sfa
#     ranking: 2013, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lid4k4dk9pu_t2v_simulation.pkl
#    4k4dk9pu
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lidu96tpd55_t2v_simulation.pkl
#    u96tpd55
#     ranking: 0312, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lidbswtap2v_t2v_simulation.pkl
#    bswtap2v
#     ranking: 2031, gender: 2, year: 1st, field: Fast track, language: Français
# perm0312_lidqkeyp2rg_t2v_simulation.pkl
#    qkeyp2rg
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2031_lidqsx2cc4b_t2v_simulation.pkl
#    qsx2cc4b
#     ranking: 2031, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidhrxpbujy_t2v_simulation.pkl
#    hrxpbujy
#     ranking: 2130, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3210_lid6uakv8nx_t2v_simulation.pkl
#    6uakv8nx
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lid4v7rjrdb_t2v_simulation.pkl
#    4v7rjrdb
#     No ranking or demographics
# permmissing_lid4v7rjrdb_t2v_simulation.pkl
# permmissing_lidf3h5amf9_t2v_simulation.pkl
#    f3h5amf9
#     No ranking or demographics
# permmissing_lidf3h5amf9_t2v_simulation.pkl
# permmissing_lidft5xsvy4_t2v_simulation.pkl
#    ft5xsvy4
#     No ranking or demographics
# permmissing_lidft5xsvy4_t2v_simulation.pkl
# perm3120_lid6fkbh35u_t2v_simulation.pkl
#    6fkbh35u
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm2103_liduagxrke6_t2v_simulation.pkl
#    uagxrke6
#     ranking: 2103, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# permmissing_lidda4vrrwz_t2v_simulation.pkl
#    da4vrrwz
#     No ranking or demographics
# permmissing_lidda4vrrwz_t2v_simulation.pkl
# permmissing_lidsuz5fszu_t2v_simulation.pkl
#    suz5fszu
#     No ranking or demographics
# permmissing_lidsuz5fszu_t2v_simulation.pkl
# perm0231_lid9bp6yz7m_t2v_simulation.pkl
#    9bp6yz7m
#     ranking: 0231, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm1230_lidfm5rcvdy_t2v_simulation.pkl
#    fm5rcvdy
#     ranking: 1230, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2130_lidr29wzm6f_t2v_simulation.pkl
#    r29wzm6f
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidy7p64n6z_t2v_simulation.pkl
#    y7p64n6z
#     ranking: 3012, gender: 4, year: 2nd, field: Chemistry, language: Deutsch
# perm2130_lidb72hbgvw_t2v_simulation.pkl
#    b72hbgvw
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidsjz2rptd_t2v_simulation.pkl
#    sjz2rptd
#     ranking: 0231, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3210_lidmcjaj2aj_t2v_simulation.pkl
#    mcjaj2aj
#     ranking: 3210, gender: 2, year: 1st, field: Chemistry, language: Français
# perm0321_lidjpccnav5_t2v_simulation.pkl
#    jpccnav5
#     ranking: 0321, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3120_lidtemu2736_t2v_simulation.pkl
#    temu2736
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Français
# permmissing_liduekptbwk_t2v_simulation.pkl
#    uekptbwk
#     No ranking or demographics
# permmissing_liduekptbwk_t2v_simulation.pkl
# perm3021_lidxcmyd5r5_t2v_simulation.pkl
#    xcmyd5r5
#     ranking: 3021, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm1302_lid6cs3annc_t2v_simulation.pkl
#    6cs3annc
#     ranking: 1302, gender: 3, year: 1st, field: Chemistry, language: Deutsch
# perm3201_lidh4hxzc6s_t2v_simulation.pkl
#    h4hxzc6s
#     ranking: 3201, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0213_lidw7asnymz_t2v_simulation.pkl
#    w7asnymz
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3120_lid2hr6mkdc_t2v_simulation.pkl
#    2hr6mkdc
#     ranking: 3120, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidd72hfax6_t2v_simulation.pkl
#    d72hfax6
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3210_lidm3d89p29_t2v_simulation.pkl
#    m3d89p29
#     ranking: 3210, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidegg8756y_t2v_simulation.pkl
#    egg8756y
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidkg43uepa_t2v_simulation.pkl
#    kg43uepa
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lidjukxh9s4_t2v_simulation.pkl
#    jukxh9s4
#     No ranking or demographics
# permmissing_lidjukxh9s4_t2v_simulation.pkl
# perm0231_lidchm4sr6j_t2v_simulation.pkl
#    chm4sr6j
#     ranking: 0231, gender: 4, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lideru7f2dt_t2v_simulation.pkl
#    eru7f2dt
#     No ranking or demographics
# permmissing_lideru7f2dt_t2v_simulation.pkl
# perm3120_lidbaqyfz2h_t2v_simulation.pkl
#    baqyfz2h
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidh8624awf_t2v_simulation.pkl
#    h8624awf
#     No ranking or demographics
# permmissing_lidh8624awf_t2v_simulation.pkl
# perm2031_lidh75kp27p_t2v_simulation.pkl
#    h75kp27p
#     ranking: 2031, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2130_lid26z3wbqz_t2v_simulation.pkl
#    26z3wbqz
#     ranking: 2130, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3012_lid2ep3hayy_t2v_simulation.pkl
#    2ep3hayy
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm1023_lidrwax4gk7_t2v_simulation.pkl
#    rwax4gk7
#     ranking: 1023, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2103_lidybxahrra_t2v_simulation.pkl
#    ybxahrra
#     ranking: 2103, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0123_lid6h5vmwys_t2v_simulation.pkl
#    6h5vmwys
#     ranking: 0123, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2031_lidrgeb7wr9_t2v_simulation.pkl
#    rgeb7wr9
#     ranking: 2031, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3120_lidn977pem4_t2v_simulation.pkl
#    n977pem4
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Français
# perm2301_lidt7728bqp_t2v_simulation.pkl
#    t7728bqp
#     ranking: 2301, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3102_lidu25vrfyy_t2v_simulation.pkl
#    u25vrfyy
#     ranking: 3102, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0213_lidrrykpeqz_t2v_simulation.pkl
#    rrykpeqz
#     ranking: 0213, gender: 2, year: 2nd, field: Biology, language: Français
# perm0321_lidxz56yha8_t2v_simulation.pkl
#    xz56yha8
#     ranking: 0321, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2013_lidbg7x3db2_t2v_simulation.pkl
#    bg7x3db2
#     ranking: 2013, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm0213_lidky8kttpv_t2v_simulation.pkl
#    ky8kttpv
#     ranking: 0213, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# permmissing_lidebt3e6ae_t2v_simulation.pkl
#    ebt3e6ae
#     No ranking or demographics
# permmissing_lidebt3e6ae_t2v_simulation.pkl
# perm0213_lidzgyc948n_t2v_simulation.pkl
#    zgyc948n
#     ranking: 0213, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidc9dj36r7_t2v_simulation.pkl
#    c9dj36r7
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidzxmtbzda_t2v_simulation.pkl
#    zxmtbzda
#     No ranking or demographics
# permmissing_lidzxmtbzda_t2v_simulation.pkl
# perm3012_lid4zsmj6s3_t2v_simulation.pkl
#    4zsmj6s3
#     ranking: 3012, gender: 2, year: 1st, field: Fast track, language: Français
# perm2103_lidr42kwnt7_t2v_simulation.pkl
#    r42kwnt7
#     ranking: 2103, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3210_lidhf8uz5t3_t2v_simulation.pkl
#    hf8uz5t3
#     ranking: 3210, gender: 2, year: 1st, field: Fast track, language: Français
# perm3120_lidz4nrhe2e_t2v_simulation.pkl
#    z4nrhe2e
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm0321_lidmy6csh6m_t2v_simulation.pkl
#    my6csh6m
#     ranking: 0321, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm3120_liduamuwrx2_t2v_simulation.pkl
#    uamuwrx2
#     ranking: 3120, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0312_lidrdy7sx9b_t2v_simulation.pkl
#    rdy7sx9b
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3120_lidtvtbbfhg_t2v_simulation.pkl
#    tvtbbfhg
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm3021_lidgk7r7cee_t2v_simulation.pkl
#    gk7r7cee
#     ranking: 3021, gender: 2, year: 1st, field: Fast track, language: Français
# perm0213_lid63v3czy6_t2v_simulation.pkl
#    63v3czy6
#     ranking: 0213, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidg6z8qykr_t2v_simulation.pkl
#    g6z8qykr
#     ranking: 3012, gender: 1, year: 2nd, field: Biology, language: Français
# perm3210_lidrve4n5nv_t2v_simulation.pkl
#    rve4n5nv
#     ranking: 3210, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3120_lidnw65tu6j_t2v_simulation.pkl
#    nw65tu6j
#     ranking: 3120, gender: 1, year: 2nd, field: Biology, language: Deutsch
# permmissing_lidrqyaqs75_t2v_simulation.pkl
#    rqyaqs75
#     No ranking or demographics
# permmissing_lidrqyaqs75_t2v_simulation.pkl
# perm3012_lidrjx9d3gf_t2v_simulation.pkl
#    rjx9d3gf
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm0231_lidv5w2e3zw_t2v_simulation.pkl
#    v5w2e3zw
#     ranking: 0231, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3012_lidbeypwbck_t2v_simulation.pkl
#    beypwbck
#     ranking: 3012, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0213_lidp6mkaa4e_t2v_simulation.pkl
#    p6mkaa4e
#     ranking: 0213, gender: 1, year: 2nd, field: Biology, language: Deutsch
# perm1230_lid3s6pz8qy_t2v_simulation.pkl
#    3s6pz8qy
#     ranking: 1230, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_liduqw5vh3j_t2v_simulation.pkl
#    uqw5vh3j
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm0321_lidp6269reg_t2v_simulation.pkl
#    p6269reg
#     ranking: 0321, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm2130_lidy8qbtkmf_t2v_simulation.pkl
#    y8qbtkmf
#     ranking: 2130, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2103_lidwnurkn96_t2v_simulation.pkl
#    wnurkn96
#     ranking: 2103, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0312_lid9hdhrrat_t2v_simulation.pkl
#    9hdhrrat
#     ranking: 0312, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm2031_lidnsj6k2rg_t2v_simulation.pkl
#    nsj6k2rg
#     ranking: 2031, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm0123_lidv5gwycag_t2v_simulation.pkl
#    v5gwycag
#     ranking: 0123, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3012_lidqevswkvj_t2v_simulation.pkl
#    qevswkvj
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2013_lide3b96acv_t2v_simulation.pkl
#    e3b96acv
#     ranking: 2013, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lidpqd874qd_t2v_simulation.pkl
#    pqd874qd
#     No ranking or demographics
# permmissing_lidpqd874qd_t2v_simulation.pkl
# perm1032_liduqven68r_t2v_simulation.pkl
#    uqven68r
#     ranking: 1032, gender: 2, year: 1st, field: Biology, language: Français
# perm2013_lidm35ub35g_t2v_simulation.pkl
#    m35ub35g
#     ranking: 2013, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm0213_lid5es5yqs8_t2v_simulation.pkl
#    5es5yqs8
#     ranking: 0213, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm2130_lidurxv4evt_t2v_simulation.pkl
#    urxv4evt
#     ranking: 2130, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3012_lidp2u7xw38_t2v_simulation.pkl
#    p2u7xw38
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lidydws5xx9_t2v_simulation.pkl
#    ydws5xx9
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3012_lidwxz98urt_t2v_simulation.pkl
#    wxz98urt
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3021_lid39htvmt5_t2v_simulation.pkl
#    39htvmt5
#     ranking: 3021, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2103_lidqk6q49f4_t2v_simulation.pkl
#    qk6q49f4
#     ranking: 2103, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidbvk4f9p3_t2v_simulation.pkl
#    bvk4f9p3
#     No ranking or demographics
# permmissing_lidbvk4f9p3_t2v_simulation.pkl
# perm2013_lidjhrkm85q_t2v_simulation.pkl
#    jhrkm85q
#     ranking: 2013, gender: 2, year: 2nd, field: Biology, language: Deutsch
# permmissing_lidxtxat8eg_t2v_simulation.pkl
#    xtxat8eg
#     No ranking or demographics
# permmissing_lidxtxat8eg_t2v_simulation.pkl
# perm1302_lid4jchqv4d_t2v_simulation.pkl
#    4jchqv4d
#     ranking: 1302, gender: 2, year: 1st, field: Chemistry, language: Français
# perm2013_lidsx3vqc32_t2v_simulation.pkl
#    sx3vqc32
#     ranking: 2013, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3120_lid5m3ka2m2_t2v_simulation.pkl
#    5m3ka2m2
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0321_lidxmh5qd3z_t2v_simulation.pkl
#    xmh5qd3z
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm2310_lidedmrufua_t2v_simulation.pkl
#    edmrufua
#     ranking: 2310, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidn238pypu_t2v_simulation.pkl
#    n238pypu
#     No ranking or demographics
# permmissing_lidn238pypu_t2v_simulation.pkl
# perm3012_lidzs35fg8g_t2v_simulation.pkl
#    zs35fg8g
#     ranking: 3012, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lid9p9gwu88_t2v_simulation.pkl
#    9p9gwu88
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lidxpyjyx4m_t2v_simulation.pkl
#    xpyjyx4m
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidp5t7d3sb_t2v_simulation.pkl
#    p5t7d3sb
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidn6zakrku_t2v_simulation.pkl
#    n6zakrku
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidfryxwskq_t2v_simulation.pkl
#    fryxwskq
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0213_lidaurjfgnn_t2v_simulation.pkl
#    aurjfgnn
#     ranking: 0213, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lid892r4czm_t2v_simulation.pkl
#    892r4czm
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3102_lidjydsy777_t2v_simulation.pkl
#    jydsy777
#     ranking: 3102, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3120_lidsr34qyfx_t2v_simulation.pkl
#    sr34qyfx
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidz8hvrhwb_t2v_simulation.pkl
#    z8hvrhwb
#     ranking: 3012, gender: 1, year: 1st, field: Fast track, language: Français
# perm3012_lidv2kw3kup_t2v_simulation.pkl
#    v2kw3kup
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Français
# perm0213_lidbje92qp8_t2v_simulation.pkl
#    bje92qp8
#     ranking: 0213, gender: 2, year: 1st, field: Fast track, language: Français
# permmissing_lidxq567sht_t2v_simulation.pkl
#    xq567sht
#     No ranking or demographics
# permmissing_lidxq567sht_t2v_simulation.pkl
# perm0213_lidxw9qt6r4_t2v_simulation.pkl
#    xw9qt6r4
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3012_liduqzxsym7_t2v_simulation.pkl
#    uqzxsym7
#     ranking: 3012, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidw25mph3c_t2v_simulation.pkl
#    w25mph3c
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm0231_lid6ruh7enb_t2v_simulation.pkl
#    6ruh7enb
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lidwbdyh5vk_t2v_simulation.pkl
#    wbdyh5vk
#     ranking: 2031, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3102_lideh9jq2bp_t2v_simulation.pkl
#    eh9jq2bp
#     ranking: 3102, gender: 1, year: 2nd, field: Biology, language: Deutsch
# perm0321_lida6t5p3sb_t2v_simulation.pkl
#    a6t5p3sb
#     ranking: 0321, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm2031_lidecy9k833_t2v_simulation.pkl
#    ecy9k833
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lids3ufctgg_t2v_simulation.pkl
#    s3ufctgg
#     No ranking or demographics
# permmissing_lids3ufctgg_t2v_simulation.pkl
# perm3120_lidfy29cvrj_t2v_simulation.pkl
#    fy29cvrj
#     ranking: 3120, gender: 3, year: 1st, field: Chemistry, language: Français
# perm3012_lid8rtwmb8t_t2v_simulation.pkl
#    8rtwmb8t
#     ranking: 3012, gender: 1, year: 2nd, field: Biology, language: Français
# perm3201_lidg43q3d94_t2v_simulation.pkl
#    g43q3d94
#     ranking: 3201, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2013_lidb2q8ay65_t2v_simulation.pkl
#    b2q8ay65
#     ranking: 2013, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lidmxh6jugj_t2v_simulation.pkl
#    mxh6jugj
#     No ranking or demographics
# permmissing_lidmxh6jugj_t2v_simulation.pkl
# perm3201_lidgu7jpyum_t2v_simulation.pkl
#    gu7jpyum
#     ranking: 3201, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3120_liday2erc3c_t2v_simulation.pkl
#    ay2erc3c
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3021_lidv2cxb3a5_t2v_simulation.pkl
#    v2cxb3a5
#     ranking: 3021, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# permmissing_lidabqwb5km_t2v_simulation.pkl
#    abqwb5km
#     No ranking or demographics
# permmissing_lidabqwb5km_t2v_simulation.pkl
# perm0231_lidytrbygud_t2v_simulation.pkl
#    ytrbygud
#     ranking: 0231, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_liddu727jdw_t2v_simulation.pkl
#    du727jdw
#     No ranking or demographics
# permmissing_liddu727jdw_t2v_simulation.pkl
# permmissing_lideq6xvgmg_t2v_simulation.pkl
#    eq6xvgmg
#     No ranking or demographics
# permmissing_lideq6xvgmg_t2v_simulation.pkl
# perm3012_lidjnjd79vh_t2v_simulation.pkl
#    jnjd79vh
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0321_lid5pt9tpaj_t2v_simulation.pkl
#    5pt9tpaj
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm0132_lidqvna6pyz_t2v_simulation.pkl
#    qvna6pyz
#     ranking: 0132, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm0231_lidp6ut882m_t2v_simulation.pkl
#    p6ut882m
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidhkvk9vt9_t2v_simulation.pkl
#    hkvk9vt9
#     ranking: 0231, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm2103_lidsz8qvgyv_t2v_simulation.pkl
#    sz8qvgyv
#     ranking: 2103, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidaraav4jr_t2v_simulation.pkl
#    araav4jr
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3120_lid3gqs3sgc_t2v_simulation.pkl
#    3gqs3sgc
#     ranking: 3120, gender: 4, year: 1st, field: Chemistry, language: Français
# permmissing_lidu5ebbg3v_t2v_simulation.pkl
#    u5ebbg3v
#     No ranking or demographics
# permmissing_lidu5ebbg3v_t2v_simulation.pkl
# perm3120_lidjwajupwj_t2v_simulation.pkl
#    jwajupwj
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3120_lidkrd7m9vb_t2v_simulation.pkl
#    krd7m9vb
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm1203_lids8w65sm5_t2v_simulation.pkl
#    s8w65sm5
#     ranking: 1203, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3102_lidj6nndaxp_t2v_simulation.pkl
#    j6nndaxp
#     ranking: 3102, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2310_lidnba9d6t2_t2v_simulation.pkl
#    nba9d6t2
#     ranking: 2310, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2103_lidx5sm9pfu_t2v_simulation.pkl
#    x5sm9pfu
#     ranking: 2103, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lidqfu6r8c7_t2v_simulation.pkl
#    qfu6r8c7
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0213_lidjwntt96k_t2v_simulation.pkl
#    jwntt96k
#     ranking: 0213, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3201_lidx844md8u_t2v_simulation.pkl
#    x844md8u
#     ranking: 3201, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm2031_lidyxf7q6ap_t2v_simulation.pkl
#    yxf7q6ap
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0231_lidst3mf78y_t2v_simulation.pkl
#    st3mf78y
#     ranking: 0231, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3021_liduenn9vgu_t2v_simulation.pkl
#    uenn9vgu
#     ranking: 3021, gender: 1, year: 1st, field: Fast track, language: Français
# perm0213_lidv9sra3j2_t2v_simulation.pkl
#    v9sra3j2
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm1320_lidrdbqasqa_t2v_simulation.pkl
#    rdbqasqa
#     ranking: 1320, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# permmissing_lidg2vjxfvw_t2v_simulation.pkl
#    g2vjxfvw
#     No ranking or demographics
# permmissing_lidg2vjxfvw_t2v_simulation.pkl
# perm0231_lidp44vw7td_t2v_simulation.pkl
#    p44vw7td
#     ranking: 0231, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2301_lid2ejxq2u8_t2v_simulation.pkl
#    2ejxq2u8
#     ranking: 2301, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2031_lidfu6nsdhs_t2v_simulation.pkl
#    fu6nsdhs
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3210_lid55yavcue_t2v_simulation.pkl
#    55yavcue
#     ranking: 3210, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2103_lidfw2ajjmt_t2v_simulation.pkl
#    fw2ajjmt
#     ranking: 2103, gender: 2, year: 1st, field: Biology, language: Français
# perm0321_lid7zjqat99_t2v_simulation.pkl
#    7zjqat99
#     ranking: 0321, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm3102_lid9pjrsbth_t2v_simulation.pkl
#    9pjrsbth
#     ranking: 3102, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm3120_lid982cf4dn_t2v_simulation.pkl
#    982cf4dn
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidnmgve3yy_t2v_simulation.pkl
#    nmgve3yy
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2310_lidjkbx6axr_t2v_simulation.pkl
#    jkbx6axr
#     ranking: 2310, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidtxg5vjzw_t2v_simulation.pkl
#    txg5vjzw
#     No ranking or demographics
# permmissing_lidtxg5vjzw_t2v_simulation.pkl
# perm3012_lidf54jkrsw_t2v_simulation.pkl
#    f54jkrsw
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0312_liddq4zzkyt_t2v_simulation.pkl
#    dq4zzkyt
#     ranking: 0312, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm0213_liduhbpoog9_t2v_simulation.pkl
#    uhbpoog9
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lid5278s35u_t2v_simulation.pkl
#    5278s35u
#     No ranking or demographics
# permmissing_lid5278s35u_t2v_simulation.pkl
# perm0312_lidvjr7tshm_t2v_simulation.pkl
#    vjr7tshm
#     ranking: 0312, gender: 4, year: 1st, field: Chemistry, language: Français
# perm0231_lidnrxpa2ac_t2v_simulation.pkl
#    nrxpa2ac
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm3102_lidvwfpuqaz_t2v_simulation.pkl
#    vwfpuqaz
#     ranking: 3102, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm2013_lid8jp62suc_t2v_simulation.pkl
#    8jp62suc
#     ranking: 2013, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lide93na59g_t2v_simulation.pkl
#    e93na59g
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3120_lidchca7sdb_t2v_simulation.pkl
#    chca7sdb
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0123_lidzy256ycq_t2v_simulation.pkl
#    zy256ycq
#     ranking: 0123, gender: 3, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lid2ae6q3hw_t2v_simulation.pkl
#    2ae6q3hw
#     ranking: 2031, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# permmissing_liddemo_t2v_simulation.pkl
#    demo
#     No ranking or demographics
# permmissing_liddemo_t2v_simulation.pkl
# perm2031_lid43e33t3h_t2v_simulation.pkl
#    43e33t3h
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidwvxkvhne_t2v_simulation.pkl
#    wvxkvhne
#     ranking: 3012, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm1320_lidmkw5afyy_t2v_simulation.pkl
#    mkw5afyy
#     ranking: 1320, gender: 1, year: 2nd, field: Biology, language: Deutsch
# perm2031_lida3vdjxy9_t2v_simulation.pkl
#    a3vdjxy9
#     ranking: 2031, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm3102_lid7t9zwtmr_t2v_simulation.pkl
#    7t9zwtmr
#     ranking: 3102, gender: 2, year: 1st, field: Fast track, language: Français
# perm3012_liduhq3p7yr_t2v_simulation.pkl
#    uhq3p7yr
#     ranking: 3012, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm2130_lidxtnmv9qf_t2v_simulation.pkl
#    xtnmv9qf
#     ranking: 2130, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3021_lidmwwddfvg_t2v_simulation.pkl
#    mwwddfvg
#     ranking: 3021, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm0231_lidvqumj3t3_t2v_simulation.pkl
#    vqumj3t3
#     ranking: 0231, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lid7cm9kver_t2v_simulation.pkl
#    7cm9kver
#     No ranking or demographics
# permmissing_lid7cm9kver_t2v_simulation.pkl
# perm2031_lid3vsn2h9f_t2v_simulation.pkl
#    3vsn2h9f
#     ranking: 2031, gender: 1, year: 1st, field: Chemistry, language: Français
# perm2130_lidqn4qjrvd_t2v_simulation.pkl
#    qn4qjrvd
#     ranking: 2130, gender: 2, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0321_lidbjy2zpww_t2v_simulation.pkl
#    bjy2zpww
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3102_lids47edumx_t2v_simulation.pkl
#    s47edumx
#     ranking: 3102, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm0312_lid7ck7mq6a_t2v_simulation.pkl
#    7ck7mq6a
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lidqdp9ant4_t2v_simulation.pkl
#    qdp9ant4
#     ranking: 0231, gender: 2, year: 2nd, field: Biology, language: Français
# perm3102_lid63xqh9t5_t2v_simulation.pkl
#    63xqh9t5
#     ranking: 3102, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lid4ak6da99_t2v_simulation.pkl
#    4ak6da99
#     ranking: 3120, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidhtf3xwbw_t2v_simulation.pkl
#    htf3xwbw
#     No ranking or demographics
# permmissing_lidhtf3xwbw_t2v_simulation.pkl
# perm3012_liddzakgq29_t2v_simulation.pkl
#    dzakgq29
#     ranking: 3012, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lidr74r26kt_t2v_simulation.pkl
#    r74r26kt
#     ranking: 0312, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm3201_lidtcnba4ca_t2v_simulation.pkl
#    tcnba4ca
#     ranking: 3201, gender: 3, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidfs32fqe3_t2v_simulation.pkl
#    fs32fqe3
#     ranking: 3012, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm2103_lidcb3z5rjs_t2v_simulation.pkl
#    cb3z5rjs
# ...
# permmissing_lid57nwt7qa_t2v_simulation.pkl
#    57nwt7qa
#     No ranking or demographics
# permmissing_lid57nwt7qa_t2v_simulation.pkl
# perm0123_lidgyerx2d9_t2v_simulation.pkl
#    gyerx2d9
#     ranking: 0123, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0213_lide8zdytr2_t2v_simulation.pkl
#    e8zdytr2
#     ranking: 0213, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2130_lidcb6wcvyn_t2v_simulation.pkl
#    cb6wcvyn
#     ranking: 2130, gender: 1, year: 1st, field: Chemistry, language: Français
# perm0231_lidew6cfr37_t2v_simulation.pkl
#    ew6cfr37
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lidwu7kdm6q_t2v_simulation.pkl
#    wu7kdm6q
#     ranking: 0312, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2031_lideau7bsmq_t2v_simulation.pkl
#    eau7bsmq
#     ranking: 2031, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2310_liduthx49rq_t2v_simulation.pkl
#    uthx49rq
#     ranking: 2310, gender: 1, year: 2nd, field: Biology, language: Français
# perm3012_lid76wvaew4_t2v_simulation.pkl
#    76wvaew4
#     ranking: 3012, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm1302_lid8ethqmkd_t2v_simulation.pkl
#    8ethqmkd
#     ranking: 1302, gender: 2, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# permmissing_lidgrhz44n7_t2v_simulation.pkl
#    grhz44n7
#     No ranking or demographics
# permmissing_lidgrhz44n7_t2v_simulation.pkl
# perm0231_lidjvxejtp9_t2v_simulation.pkl
#    jvxejtp9
#     ranking: 0231, gender: 2, year: 2nd, field: Biology, language: Français
# perm3201_lidzgs84jfy_t2v_simulation.pkl
#    zgs84jfy
#     ranking: 3201, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lidww2m3qch_t2v_simulation.pkl
#    ww2m3qch
#     No ranking or demographics
# permmissing_lidww2m3qch_t2v_simulation.pkl
# permmissing_lidp5ac3mu7_t2v_simulation.pkl
#    p5ac3mu7
#     No ranking or demographics
# permmissing_lidp5ac3mu7_t2v_simulation.pkl
# permmissing_lidb25u3a4u_t2v_simulation.pkl
#    b25u3a4u
#     No ranking or demographics
# permmissing_lidb25u3a4u_t2v_simulation.pkl
# perm3120_lidjcrv9m9j_t2v_simulation.pkl
#    jcrv9m9j
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0213_lid9sgu2tbg_t2v_simulation.pkl
#    9sgu2tbg
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3012_lidnfshnktq_t2v_simulation.pkl
#    nfshnktq
#     ranking: 3012, gender: 2, year: 2nd, field: Biology, language: Deutsch
# perm2031_lid9xc2v9vu_t2v_simulation.pkl
#    9xc2v9vu
#     ranking: 2031, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidmgr68u6f_t2v_simulation.pkl
#    mgr68u6f
#     No ranking or demographics
# permmissing_lidmgr68u6f_t2v_simulation.pkl
# perm0231_liddk43m2pe_t2v_simulation.pkl
#    dk43m2pe
#     ranking: 0231, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3012_lidakgpua6j_t2v_simulation.pkl
#    akgpua6j
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm3102_lid5a69aw4h_t2v_simulation.pkl
#    5a69aw4h
#     ranking: 3102, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lid7g36g5tz_t2v_simulation.pkl
#    7g36g5tz
#     ranking: 0312, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm2130_lidryfqnvfh_t2v_simulation.pkl
#    ryfqnvfh
#     ranking: 2130, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2130_lidpggnv6xw_t2v_simulation.pkl
#    pggnv6xw
#     ranking: 2130, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0123_lid4vtjgtja_t2v_simulation.pkl
#    4vtjgtja
#     ranking: 0123, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2013_lidsh6tu9g2_t2v_simulation.pkl
#    sh6tu9g2
#     ranking: 2013, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# permmissing_lid4rxkb9bc_t2v_simulation.pkl
#    4rxkb9bc
#     No ranking or demographics
# permmissing_lid4rxkb9bc_t2v_simulation.pkl
# perm0312_lidaj47uhb9_t2v_simulation.pkl
#    aj47uhb9
#     ranking: 0312, gender: 1, year: 1st, field: Chemistry, language: Français
# perm1023_lidbed4zkv2_t2v_simulation.pkl
#    bed4zkv2
#     ranking: 1023, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lids2up6gmm_t2v_simulation.pkl
#    s2up6gmm
#     ranking: 0231, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm2031_lidqner25zp_t2v_simulation.pkl
#    qner25zp
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm0231_lid8pskk9tr_t2v_simulation.pkl
#    8pskk9tr
#     ranking: 0231, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lid9qvk2wew_t2v_simulation.pkl
#    9qvk2wew
#     ranking: 2130, gender: 2, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm0213_lid2xh9zuvc_t2v_simulation.pkl
#    2xh9zuvc
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2013_lidxngb9hff_t2v_simulation.pkl
#    xngb9hff
#     ranking: 2013, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lid8ga2zn5h_t2v_simulation.pkl
#    8ga2zn5h
#     ranking: 2031, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3012_lidu4zu9xxc_t2v_simulation.pkl
#    u4zu9xxc
#     ranking: 3012, gender: 2, year: 1st, field: Biology, language: Français
# perm2013_lid7fj2vydr_t2v_simulation.pkl
#    7fj2vydr
#     ranking: 2013, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm2310_lideqdntxer_t2v_simulation.pkl
#    eqdntxer
#     ranking: 2310, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidmvhzrv2y_t2v_simulation.pkl
#    mvhzrv2y
#     No ranking or demographics
# permmissing_lidmvhzrv2y_t2v_simulation.pkl
# perm3201_lidssz3uyqn_t2v_simulation.pkl
#    ssz3uyqn
#     ranking: 3201, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3210_lid22wyn9xy_t2v_simulation.pkl
#    22wyn9xy
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Français
# perm2031_lidvqebanqv_t2v_simulation.pkl
#    vqebanqv
#     ranking: 2031, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lida3tffvsb_t2v_simulation.pkl
#    a3tffvsb
#     No ranking or demographics
# permmissing_lida3tffvsb_t2v_simulation.pkl
# perm1320_lidfddsxudu_t2v_simulation.pkl
#    fddsxudu
#     ranking: 1320, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# permmissing_lid8n8w8zkd_t2v_simulation.pkl
#    8n8w8zkd
#     No ranking or demographics
# permmissing_lid8n8w8zkd_t2v_simulation.pkl
# perm3210_lidz5dzzgk5_t2v_simulation.pkl
#    z5dzzgk5
#     ranking: 3210, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3120_lidke6msbfr_t2v_simulation.pkl
#    ke6msbfr
#     ranking: 3120, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3012_lidzxp438xr_t2v_simulation.pkl
#    zxp438xr
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3021_lidm9u6p93a_t2v_simulation.pkl
#    m9u6p93a
#     ranking: 3021, gender: 2, year: 2nd, field: Biology, language: Français
# permmissing_lidbbdd557u_t2v_simulation.pkl
#    bbdd557u
#     No ranking or demographics
# permmissing_lidbbdd557u_t2v_simulation.pkl
# perm2130_lidcwgvxrvx_t2v_simulation.pkl
#    cwgvxrvx
#     ranking: 2130, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm0321_lid4rjjdez9_t2v_simulation.pkl
#    4rjjdez9
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm2103_lidyez72a8b_t2v_simulation.pkl
#    yez72a8b
#     ranking: 2103, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# permmissing_lidmb8mn3zx_t2v_simulation.pkl
#    mb8mn3zx
#     No ranking or demographics
# permmissing_lidmb8mn3zx_t2v_simulation.pkl
# perm3012_lid3kzp9bet_t2v_simulation.pkl
#    3kzp9bet
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidphcrjd9q_t2v_simulation.pkl
#    phcrjd9q
#     No ranking or demographics
# permmissing_lidphcrjd9q_t2v_simulation.pkl
# perm0213_lidtzpqpfaa_t2v_simulation.pkl
#    tzpqpfaa
#     ranking: 0213, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm0312_lidtt5n8d2r_t2v_simulation.pkl
#    tt5n8d2r
#     ranking: 0312, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3120_lid5j7hdews_t2v_simulation.pkl
#    5j7hdews
#     ranking: 3120, gender: 1, year: 1st, field: Chemistry, language: Français
# permmissing_lidu9gxp77h_t2v_simulation.pkl
#    u9gxp77h
#     No ranking or demographics
# permmissing_lidu9gxp77h_t2v_simulation.pkl
# perm0321_lidk8x4ru7k_t2v_simulation.pkl
#    k8x4ru7k
#     ranking: 0321, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm3021_lidsm8sfpcg_t2v_simulation.pkl
#    sm8sfpcg
#     ranking: 3021, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# permmissing_lidetxwsdtx_t2v_simulation.pkl
#    etxwsdtx
#     No ranking or demographics
# permmissing_lidetxwsdtx_t2v_simulation.pkl
# perm0231_lids7mdq5tk_t2v_simulation.pkl
#    s7mdq5tk
#     ranking: 0231, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm2310_lid5y535ct3_t2v_simulation.pkl
#    5y535ct3
#     ranking: 2310, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# perm2031_liddjnysnd6_t2v_simulation.pkl
#    djnysnd6
#     ranking: 2031, gender: 2, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm0321_lidprr8qsns_t2v_simulation.pkl
#    prr8qsns
#     ranking: 0321, gender: 1, year: 2nd, field: Biology, language: Français
# perm3102_lidneuwx57b_t2v_simulation.pkl
#    neuwx57b
#     ranking: 3102, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm3120_lidfzagvhvf_t2v_simulation.pkl
#    fzagvhvf
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2130_lidsrmr7pcp_t2v_simulation.pkl
#    srmr7pcp
#     ranking: 2130, gender: 2, year: 1st, field: Biology, language: Français
# perm3102_lids78drqcg_t2v_simulation.pkl
#    s78drqcg
#     ranking: 3102, gender: 3, year: 2nd, field: Biology, language: Français
# perm3120_lidt3dwkezr_t2v_simulation.pkl
#    t3dwkezr
#     ranking: 3120, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm1230_lidqjfn2j8z_t2v_simulation.pkl
#    qjfn2j8z
#     ranking: 1230, gender: 1, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm2013_lid47ce49e4_t2v_simulation.pkl
#    47ce49e4
#     ranking: 2013, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm1023_lidg4xpwwac_t2v_simulation.pkl
#    g4xpwwac
#     ranking: 1023, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3012_lid9wdm7zue_t2v_simulation.pkl
#    9wdm7zue
#     ranking: 3012, gender: 2, year: 1st, field: Chemistry, language: Français
# perm3201_lidszvqb37f_t2v_simulation.pkl
#    szvqb37f
#     ranking: 3201, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidhrhu4yph_t2v_simulation.pkl
#    hrhu4yph
#     ranking: 2130, gender: 1, year: 1st, field: Biology, language: Français
# permmissing_lidktd99zh9_t2v_simulation.pkl
#    ktd99zh9
#     No ranking or demographics
# permmissing_lidktd99zh9_t2v_simulation.pkl
# perm0231_lidq4z45p85_t2v_simulation.pkl
#    q4z45p85
#     ranking: 0231, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm2130_lidu6c3cp6c_t2v_simulation.pkl
#    u6c3cp6c
#     ranking: 2130, gender: 1, year: 1st, field: Chemistry, language: Français
# perm1023_lidr78kg7d3_t2v_simulation.pkl
#    r78kg7d3
#     ranking: 1023, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lid6bq62prp_t2v_simulation.pkl
#    6bq62prp
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, Textiles, language: Deutsch
# permmissing_lid3pz22p3a_t2v_simulation.pkl
#    3pz22p3a
#     No ranking or demographics
# permmissing_lid3pz22p3a_t2v_simulation.pkl
# perm3021_lid4vuc8rr3_t2v_simulation.pkl
#    4vuc8rr3
#     ranking: 3021, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# permmissing_lid6hbvyq5m_t2v_simulation.pkl
#    6hbvyq5m
#     No ranking or demographics
# permmissing_lid6hbvyq5m_t2v_simulation.pkl
# perm0312_lidvbym9sms_t2v_simulation.pkl
#    vbym9sms
#     ranking: 0312, gender: 2, year: 1st, field: Fast track, language: Français
# perm0321_lidz8dtc572_t2v_simulation.pkl
#    z8dtc572
#     ranking: 0321, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lidgpq26qq9_t2v_simulation.pkl
#    gpq26qq9
#     ranking: 3120, gender: 1, year: 2nd, field: Chemistry, language: Français
# perm3012_lid5zqfzwjg_t2v_simulation.pkl
#    5zqfzwjg
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm2130_lidvckta85p_t2v_simulation.pkl
#    vckta85p
#     ranking: 2130, gender: 2, year: 1st, field: Pharma Chemistry, language: Deutsch
# perm3012_liddmdc53tx_t2v_simulation.pkl
#    dmdc53tx
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Français
# perm3012_lidd7777ske_t2v_simulation.pkl
#    d7777ske
#     ranking: 3012, gender: 1, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# perm3210_lid3se7z466_t2v_simulation.pkl
#    3se7z466
#     ranking: 3210, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidf4hqtjt4_t2v_simulation.pkl
#    f4hqtjt4
#     No ranking or demographics
# permmissing_lidf4hqtjt4_t2v_simulation.pkl
# perm3012_lid3qwayak9_t2v_simulation.pkl
#    3qwayak9
#     ranking: 3012, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm3120_lidpyamv67t_t2v_simulation.pkl
#    pyamv67t
#     ranking: 3120, gender: 2, year: 2nd, field: Chemistry, language: Deutsch
# perm1320_lid7xwv3xfe_t2v_simulation.pkl
#    7xwv3xfe
#     ranking: 1320, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3012_lidoikzz9af_t2v_simulation.pkl
#    oikzz9af
#     ranking: 3012, gender: 1, year: 1st, field: Chemistry, language: Deutsch
# perm3021_lidm4frzqy6_t2v_simulation.pkl
#    m4frzqy6
#     ranking: 3021, gender: 2, year: 2nd, field: Chemistry, language: Français
# perm0213_lidm4zvafhs_t2v_simulation.pkl
#    m4zvafhs
#     ranking: 0213, gender: 1, year: 1st, field: Chemistry, language: Français
# perm2013_lidrmd35un4_t2v_simulation.pkl
#    rmd35un4
#     ranking: 2013, gender: 1, year: 2nd, field: Chemistry, language: Deutsch
# perm2031_lidm749z8u9_t2v_simulation.pkl
#    m749z8u9
#     ranking: 2031, gender: 2, year: 3rd, field: Chemistry, Textiles, language: Deutsch
# permmissing_lidkj5abt7s_t2v_simulation.pkl
#    kj5abt7s
#     No ranking or demographics
# permmissing_lidkj5abt7s_t2v_simulation.pkl
# permmissing_lid84khcu2r_t2v_simulation.pkl
#    84khcu2r
#     No ranking or demographics
# permmissing_lid84khcu2r_t2v_simulation.pkl
# permmissing_lidqyz6cdae_t2v_simulation.pkl
#    qyz6cdae
#     No ranking or demographics
# permmissing_lidqyz6cdae_t2v_simulation.pkl
# perm3102_lidpmd5dyu3_t2v_simulation.pkl
#    pmd5dyu3
#     ranking: 3102, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm2310_lidvh8vedkw_t2v_simulation.pkl
#    vh8vedkw
#     ranking: 2310, gender: 1, year: 2nd, field: Biology, language: Français
# perm2130_lid6rfakyp7_t2v_simulation.pkl
#    6rfakyp7
#     ranking: 2130, gender: 2, year: 1st, field: Chemistry, language: Deutsch
# perm0231_lid88kjzd8b_t2v_simulation.pkl
#    88kjzd8b
#     ranking: 0231, gender: 2, year: 3rd, field: Chemistry, language: Deutsch
# perm2013_lidzkrr45y5_t2v_simulation.pkl
#    zkrr45y5
#     ranking: 2013, gender: 1, year: 1st, field: Chemistry, Textiles, language: Deutsch
# perm3012_lid46bty2zg_t2v_simulation.pkl
#    46bty2zg
#     ranking: 3012, gender: 2, year: 1st, field: Fast track, language: Français
# perm2103_lid4aaspwgs_t2v_simulation.pkl
#    4aaspwgs
#     ranking: 2103, gender: 1, year: 3rd, field: Chemistry, language: Deutsch
# perm3021_lid26mtbtye_t2v_simulation.pkl
#    26mtbtye
#     ranking: 3021, gender: 1, year: 2nd, field: Chemistry, language: Français
# permmissing_lidusa5gyb9_t2v_simulation.pkl
#    usa5gyb9
#     No ranking or demographics
# permmissing_lidusa5gyb9_t2v_simulation.pkl
# permmissing_lidny2yewe7_t2v_simulation.pkl
#    ny2yewe7
#     No ranking or demographics
# permmissing_lidny2yewe7_t2v_simulation.pkl
# perm3012_lid4e438nww_t2v_simulation.pkl
#    4e438nww
#     ranking: 3012, gender: 2, year: 1st, field: Biology, language: Français
# perm2130_lid2cetp8yc_t2v_simulation.pkl
#    2cetp8yc
#     ranking: 2130, gender: 2, year: 1st, field: Chemistry, language: Deutsch

# %% [markdown]
# # Sequence to Features

# %%
# settings
settings_pipeline = {
    'experiment':{
        'class_name': 'binconcepts',
        'root_name': 'logistic_regression_R',
        'name': 'logistic_regression',
    },
    'data': {
        'pipeline': {
            'sequencer': 'simplemorestates_secondsflat',
            'sequencer_dragasclick': True,
            'break_threshold': 0.6,
            'concatenator': {
                'type': 'chemconcat',
                'tasks': ['2']
            },
            'demographic_filter': 'chemlab',
            'event_filter': 'nofilt',
            'break_threshold': 0.6,
            'break_filter': 'nobrfilt',
            'adjuster': 'full'
        },
        'min_length': 0,
        'filters': {'interactionlimit':10},
        'adjuster': {'limit':300}
    },
    'ML': {
        'pipeline': {
            'scorer': 'none',
        },
    },
    'paths': {'sequenced_simulations': '../data/beerslaw/logistic_regression/sequenced/'}
}

# %% [markdown]
# ## Action Count

# %%
# Parameters for action count
settings_pipeline['data']['pipeline']['encoder'] = '1hot'
settings_pipeline['data']['pipeline']['aggregator'] = 'aveagg'

# Create data
pipeline = PipelineMaker(settings_pipeline)
sequences, labels, indices, id_dictionary = pipeline.build_data()

# Create DF
data_r = []
for i, seq in enumerate(sequences):
    row = [id_dictionary['sequences'][indices[i]]['learner_id']] + list(seq) + [labels[i]]
    data_r.append(row)

columns = ['lid'] + list(sequencer.get_states()) + ['binconcepts']
df_r = pd.DataFrame(data_r, columns=columns)
df_r['permutation'] = df_r['lid'].apply(lambda x: ranks.loc[x]['ranking'])
df_r['language'] = df_r['lid'].apply(lambda x: ranks.loc[x]['language'])
df_r['field'] = df_r['lid'].apply(lambda x: ranks.loc[x]['field'])
df_r['year'] = df_r['lid'].apply(lambda x: ranks.loc[x]['year'])
df_r['gender'] = df_r['lid'].apply(lambda x: ranks.loc[x]['gender'])

# Action count
df_r.to_csv('../data/beerslaw/logistic_regression/action_count.tsv', sep='\t')

# %%
df_r
# Out:
#           lid  greengreen_other  greenred_other  notgreennotred_other  \
# 0    svdphyjs          0.115789        0.063158              0.021053
# 1    gc663sap          0.000000        0.015625              0.000000
# 2    8nh4zvcp          0.000000        0.019608              0.000000
# 3    5f4q4ng5          0.000000        0.013699              0.075342
# 4    ujpk3gf4          0.000000        0.044444              0.000000
# ..        ...               ...             ...                   ...
# 249  m749z8u9          0.000000        0.008516              0.000000
# 250  88kjzd8b          0.000000        0.016949              0.000000
# 251  zkrr45y5          0.000000        0.000000              0.000000
# 252  26mtbtye          0.000000        0.000000              0.000000
# 253  4e438nww          0.000000        0.007177              0.031100
#
#      noobserved_other  greengreen_concentration  greenred_concentration  \
# 0            0.031579                  0.021053                0.052632
# 1            0.031250                  0.000000                0.000000
# 2            0.098039                  0.000000                0.000000
# 3            0.150685                  0.000000                0.000000
# 4            0.044444                  0.000000                0.088889
# ..                ...                       ...                     ...
# 249          0.000000                  0.590024                0.107056
# 250          0.033898                  0.118644                0.203390
# 251          0.025641                  0.000000                0.000000
# 252          0.045455                  0.000000                0.000000
# 253          0.014354                  0.000000                0.000000
#
#      notgreennotred_concentration  noobserved_concentration  greengreen_width  \
# 0                        0.010526                  0.000000          0.010526
# 1                        0.000000                  0.109375          0.000000
# 2                        0.000000                  0.313725          0.000000
# 3                        0.027397                  0.068493          0.000000
# 4                        0.000000                  0.177778          0.000000
# ..                            ...                       ...               ...
# 249                      0.000000                  0.000000          0.002433
# 250                      0.000000                  0.000000          0.067797
# 251                      0.000000                  0.128205          0.000000
# 252                      0.000000                  0.000000          0.000000
# 253                      0.291866                  0.220096          0.000000
#
#      ...  greengreen_break  greenred_break  notgreennotred_break  \
# 0    ...          0.094737        0.084211              0.042105
# 1    ...          0.000000        0.031250              0.000000
# 2    ...          0.000000        0.029412              0.000000
# 3    ...          0.000000        0.000000              0.068493
# 4    ...          0.000000        0.133333              0.000000
# ..   ...               ...             ...                   ...
# 249  ...          0.197080        0.055961              0.000000
# 250  ...          0.067797        0.169492              0.016949
# 251  ...          0.025641        0.025641              0.000000
# 252  ...          0.000000        0.000000              0.000000
# 253  ...          0.000000        0.026316              0.141148
#
#      noobserved_break  binconcepts  permutation  language  \
# 0            0.052632            1         2013   Deutsch
# 1            0.234375            1         3120  Français
# 2            0.245098            0         0213   Deutsch
# 3            0.205479            0         3021  Français
# 4            0.111111            0         3012   Deutsch
# ..                ...          ...          ...       ...
# 249          0.003650            1         2031   Deutsch
# 250          0.016949            1         0231   Deutsch
# 251          0.217949            1         2013   Deutsch
# 252          0.181818            0         3021  Français
# 253          0.114833            0         3012  Français
#
#                    field  year  gender
# 0              Chemistry   1st       2
# 1              Chemistry   2nd       1
# 2    Chemistry, Textiles   3rd       1
# 3              Chemistry   1st       1
# 4    Chemistry, Textiles   3rd       1
# ..                   ...   ...     ...
# 249  Chemistry, Textiles   3rd       2
# 250            Chemistry   3rd       2
# 251  Chemistry, Textiles   1st       1
# 252            Chemistry   2nd       1
# 253              Biology   1st       2
#
# [254 rows x 36 columns]

# %% [markdown]
# ## Action Span

# %%
# Parameters for action span
settings_pipeline['data']['pipeline']['encoder'] = 'actionspan'
settings_pipeline['data']['pipeline']['aggregator'] = 'normagg'

# Create data
pipeline = PipelineMaker(settings_pipeline)
sequences, labels, indices, id_dictionary = pipeline.build_data()

# Create DF
data_r = []
for i, seq in enumerate(sequences):
    row = [id_dictionary['sequences'][indices[i]]['learner_id']] + list(seq) + [labels[i]]
    data_r.append(row)

columns = ['lid'] + list(sequencer.get_states()) + ['binconcepts']
df_r = pd.DataFrame(data_r, columns=columns)
df_r['permutation'] = df_r['lid'].apply(lambda x: ranks.loc[x]['ranking'])
df_r['language'] = df_r['lid'].apply(lambda x: ranks.loc[x]['language'])
df_r['field'] = df_r['lid'].apply(lambda x: ranks.loc[x]['field'])
df_r['year'] = df_r['lid'].apply(lambda x: ranks.loc[x]['year'])
df_r['gender'] = df_r['lid'].apply(lambda x: ranks.loc[x]['gender'])

# Action count
df_r.to_csv('../data/beerslaw/logistic_regression/action_span.tsv', sep='\t')
