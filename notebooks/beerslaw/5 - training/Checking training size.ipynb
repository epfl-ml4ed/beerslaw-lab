# %%
import os
import pickle

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
with open('./debug_filter_data.pkl', 'rb') as fp:
    filter_data = pickle.load(fp)

# %%
len(filter_data['index'])
for idx in filter_data['sequences']:
    with open(filter_data['sequences'][idx]['path'], 'rb') as fp:
        sim = pickle.load(fp)
        print('length: {}, #interactions: {}'.format(sim['last_timestamp'], len(sim['sequence'])))
# Out:
# length: 530.434, #interactions: 78
# length: 1221.144, #interactions: 150
# length: 275.756, #interactions: 21
# length: 731.364, #interactions: 57
# length: 198.533, #interactions: 18
# length: 590.083, #interactions: 46
# length: 616.79, #interactions: 73
# length: 473.809, #interactions: 50
# length: 164.675, #interactions: 38
# length: 1173.947, #interactions: 53
# length: 693.262, #interactions: 69
# length: 172.264, #interactions: 13
# length: 280.16, #interactions: 107
# length: 462.187, #interactions: 134
# length: 896.245, #interactions: 36
# length: 355.256, #interactions: 123
# length: 363.454, #interactions: 29
# length: 368.79, #interactions: 45
# length: 1105.526, #interactions: 73
# length: 826.635, #interactions: 149
# length: 573.926, #interactions: 47
# length: 473.356, #interactions: 66
# length: 219.132, #interactions: 35
# length: 147.61, #interactions: 13
# length: 427.041, #interactions: 105
# length: 475.196, #interactions: 64
# ...

# %%
len(filter_data['index'])
# Out:
# 227
