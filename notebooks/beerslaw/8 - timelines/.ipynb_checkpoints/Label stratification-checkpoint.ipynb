# %%
import os
import re
import yaml
import pickle

import ipyplot
import pandas as pd

# %%
timelines_path = '../../reports/timelines/colour timelines/'
timelines_notebook = 'http://localhost:8888/view/notebooks/8%20-%20timelines/colour%20timelines/'
addresses = os.listdir(timelines_path)
addresses = [ad for ad in addresses if 'png' in ad]
local_addresses = [(timelines_path + addr) for addr in addresses]

# %%
with open('../../data/post_test/rankings.pkl', 'rb') as fp:
    rankings = pickle.load(fp)
    id_rankings = {rankings.iloc[i]['username']: rankings.iloc[i]['ranking'] for i in range(len(rankings))}

# %%
def get_map(label_map:str) -> dict:
    if label_map == 'vector_labels':
        map_path = '../../data/experiment_keys/permutation_maps/vector_binary.yaml'
        
    with open(map_path) as fp:
        return yaml.load(fp, Loader=yaml.FullLoader)
    
def images_labels(addresses:list, id_rankings:dict, label_map:dict):
    permutation = re.compile('^p([0-9]+)_')
    learner_id = re.compile('_l([A-z0-9]+)_t')
    task = re.compile('_t([0-9]+).')
    
    permutations = []
    learners = []
    labels = []
    tasks = []
    for address in addresses:
        try:
            p = permutation.findall(address)[0]
            permutations.append(p)

            l = learner_id.findall(address)[0]
            learners.append(l)

            labels.append(label_map['map'][p])

            t = task.findall(address)[0]
            tasks.append(t)
        except IndexError:
            permutations.append('missing')

            l = learner_id.findall(address)[0]
            learners.append(l)

            labels.append('none')

            t = task.findall(address)[0]
            tasks.append(t)
        
    return permutations, learners, labels, tasks

def plot_for_task(addresses:list, labels:list, tasks:list, task:int):
    indices = [i for i in range(len(tasks)) if tasks[i] == str(task)]
    ad = [addresses[idx] for idx in indices]
    labs = [labels[idx] for idx in indices]
    ipyplot.plot_class_tabs(ad, labs, max_imgs_per_tab=10, img_width=700)

# %%
label_map = get_map('vector_labels')
permutations, learners, labels, tasks = images_labels(addresses, id_rankings, label_map)
plot_for_task(local_addresses, labels, tasks, 2)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mfrpxd7mucGBvM5HNpdg3V {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mfrpxd7mucGBvM5HNpdg3V {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mfrpxd7mucGBvM5HNpdg3V {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mfrpxd7mucGBvM5HNpdg3V:checked ~ #ipyplot-html-viewer-textarea-mfrpxd7mucGBvM5HNpdg3V {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mfrpxd7mucGBvM5HNpdg3V:checked + #ipyplot-html-viewer-label-mfrpxd7mucGBvM5HNpdg3V:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-mfrpxd7mucGBvM5HNpdg3V">
#         <label id="ipyplot-html-viewer-label-mfrpxd7mucGBvM5HNpdg3V" for="ipyplot-html-viewer-toggle-mfrpxd7mucGBvM5HNpdg3V">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-mfrpxd7mucGBvM5HNpdg3V" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 {
#                 display: none;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 + label.ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4:checked + label.ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 ~ .tab {
#                 display: none
#             }
#     #tabfHXc6iMz3fupomM4RUyeLa:checked ~ .tab.contentfHXc6iMz3fupomM4RUyeLa,#tab76g5YXqSgxK93hA26Vnk2Y:checked ~ .tab.content76g5YXqSgxK93hA26Vnk2Y,#tabQj7k6jYV7Vz3CMLW3Wb5Fm:checked ~ .tab.contentQj7k6jYV7Vz3CMLW3Wb5Fm,#tabPQ3dEcHcdo8j6FebuUmAHC:checked ~ .tab.contentPQ3dEcHcdo8j6FebuUmAHC,#tab5EdMGTSvBRujWSSpWKtf4X:checked ~ .tab.content5EdMGTSvBRujWSSpWKtf4X,#tabdVYzLkn7ubh7iU56gfKDea:checked ~ .tab.contentdVYzLkn7ubh7iU56gfKDea,#tabZpWxYqgDhwAGZUcVBpeEEV:checked ~ .tab.contentZpWxYqgDhwAGZUcVBpeEEV,#tabHoLEJndn4ajWsJFj9Sxkru:checked ~ .tab.contentHoLEJndn4ajWsJFj9Sxkru,#tabCvYKgrAnETN6TkVMhMk8uY:checked ~ .tab.contentCvYKgrAnETN6TkVMhMk8uY{ display: block; }</style><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabfHXc6iMz3fupomM4RUyeLa" checked /><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabfHXc6iMz3fupomM4RUyeLa">000</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tab76g5YXqSgxK93hA26Vnk2Y"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tab76g5YXqSgxK93hA26Vnk2Y">001</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabQj7k6jYV7Vz3CMLW3Wb5Fm"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabQj7k6jYV7Vz3CMLW3Wb5Fm">010</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabPQ3dEcHcdo8j6FebuUmAHC"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabPQ3dEcHcdo8j6FebuUmAHC">011</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tab5EdMGTSvBRujWSSpWKtf4X"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tab5EdMGTSvBRujWSSpWKtf4X">100</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabdVYzLkn7ubh7iU56gfKDea"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabdVYzLkn7ubh7iU56gfKDea">101</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabZpWxYqgDhwAGZUcVBpeEEV"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabZpWxYqgDhwAGZUcVBpeEEV">110</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabHoLEJndn4ajWsJFj9Sxkru"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabHoLEJndn4ajWsJFj9Sxkru">111</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabCvYKgrAnETN6TkVMhMk8uY"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabCvYKgrAnETN6TkVMhMk8uY">none</label><div class="tab contentfHXc6iMz3fupomM4RUyeLa">
#         <style>
#         #ipyplot-imgs-container-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Bx4nW2gv6r7MVTVe4b9diU">
#     <div class="ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU">
#         <div id="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-VjbB9dfi2pTjRzzudMYDwU" class="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p2103_lh543nsc8_t2.png</h4><img src="../../reports/timelines/colour timelines/p2103_lh543nsc8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
# <div>
#         <style>
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 {
#                 display: none;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 + label.ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4:checked + label.ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-h6t39w69XTQC2ZkpB68oz4 ~ .tab {
#                 display: none
#             }
#     #tabfHXc6iMz3fupomM4RUyeLa:checked ~ .tab.contentfHXc6iMz3fupomM4RUyeLa,#tab76g5YXqSgxK93hA26Vnk2Y:checked ~ .tab.content76g5YXqSgxK93hA26Vnk2Y,#tabQj7k6jYV7Vz3CMLW3Wb5Fm:checked ~ .tab.contentQj7k6jYV7Vz3CMLW3Wb5Fm,#tabPQ3dEcHcdo8j6FebuUmAHC:checked ~ .tab.contentPQ3dEcHcdo8j6FebuUmAHC,#tab5EdMGTSvBRujWSSpWKtf4X:checked ~ .tab.content5EdMGTSvBRujWSSpWKtf4X,#tabdVYzLkn7ubh7iU56gfKDea:checked ~ .tab.contentdVYzLkn7ubh7iU56gfKDea,#tabZpWxYqgDhwAGZUcVBpeEEV:checked ~ .tab.contentZpWxYqgDhwAGZUcVBpeEEV,#tabHoLEJndn4ajWsJFj9Sxkru:checked ~ .tab.contentHoLEJndn4ajWsJFj9Sxkru,#tabCvYKgrAnETN6TkVMhMk8uY:checked ~ .tab.contentCvYKgrAnETN6TkVMhMk8uY{ display: block; }</style><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabfHXc6iMz3fupomM4RUyeLa" checked /><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabfHXc6iMz3fupomM4RUyeLa">000</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tab76g5YXqSgxK93hA26Vnk2Y"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tab76g5YXqSgxK93hA26Vnk2Y">001</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabQj7k6jYV7Vz3CMLW3Wb5Fm"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabQj7k6jYV7Vz3CMLW3Wb5Fm">010</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabPQ3dEcHcdo8j6FebuUmAHC"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabPQ3dEcHcdo8j6FebuUmAHC">011</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tab5EdMGTSvBRujWSSpWKtf4X"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tab5EdMGTSvBRujWSSpWKtf4X">100</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabdVYzLkn7ubh7iU56gfKDea"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabdVYzLkn7ubh7iU56gfKDea">101</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabZpWxYqgDhwAGZUcVBpeEEV"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabZpWxYqgDhwAGZUcVBpeEEV">110</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabHoLEJndn4ajWsJFj9Sxkru"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabHoLEJndn4ajWsJFj9Sxkru">111</label><input class="ipyplot-tab-h6t39w69XTQC2ZkpB68oz4" type="radio" name="tabs-h6t39w69XTQC2ZkpB68oz4" id="tabCvYKgrAnETN6TkVMhMk8uY"/><label class="ipyplot-tab-label-h6t39w69XTQC2ZkpB68oz4" for="tabCvYKgrAnETN6TkVMhMk8uY">none</label><div class="tab contentfHXc6iMz3fupomM4RUyeLa">
#         <style>
#         #ipyplot-imgs-container-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Bx4nW2gv6r7MVTVe4b9diU">
#     <div class="ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU">
#         <div id="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-VjbB9dfi2pTjRzzudMYDwU" class="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p2103_lh543nsc8_t2.png</h4><img src="../../reports/timelines/colour timelines/p2103_lh543nsc8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-VjbB9dfi2pTjRzzudMYDwU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU">
#         <div id="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-E6MabzcpVA6i7gt42aV8Jb" class="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p0312_lo9ffsiwt_t2.png</h4><img src="../../reports/timelines/colour timelines/p0312_lo9ffsiwt_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-E6MabzcpVA6i7gt42aV8Jb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Bx4nW2gv6r7MVTVe4b9diU">
#         <div id="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU-hjKcfRKdV6sDzoWiKtBASg" class="ipyplot-content-div-Bx4nW2gv6r7MVTVe4b9diU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p0123_lbezdgyya_t2.png</h4><img src="../../reports/timelines/colour timelines/p0123_lbezdgyya_t2.png"/>
