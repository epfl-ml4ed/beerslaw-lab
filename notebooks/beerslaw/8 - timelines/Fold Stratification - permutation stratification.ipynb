# %%
import os
import re
import yaml
import pickle

import ipyplot
import numpy as np
import pandas as pd

import tensorflow as tf

import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Data

# %%
cd ../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %%
experiment_path = '../experiments/test_plot/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_28_4/'

# Gridsearch folds
gs_file = os.listdir(experiment_path + '/gridsearch results/')[0]
with open(experiment_path + '/gridsearch results/' + gs_file, 'rb') as fp:
    gs = pickle.load(fp)
    gs = gs.get_results()
    folds = gs[0]['fold_index']

# oversampling indices
xval_path = os.listdir(experiment_path + '/results/')[0]
with open(experiment_path + '/results/' + xval_path, 'rb') as fp:
    xval_object = pickle.load(fp)
    oversampled_indices = xval_object[0]['oversample_indices']
    test_indices = xval_object[0]['test_indices']
    
# id dictionary
with open(experiment_path + 'config.yaml', 'rb') as fp:
    config = pickle.load(fp)
    id_dictionary = config['id_dictionary']

# %%
cd ../notebooks/8 - timelines/
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/notebooks/8 - timelines

# %%
timelines_path = '../../reports/timelines/colour timelines/'
addresses = os.listdir(timelines_path)
addresses = [ad for ad in addresses if 'png' in ad]
local_addresses = [(timelines_path + addr) for addr in addresses]

# %% [markdown]
# # Functions

# %%
def get_id_folds(folds:dict, oversampled_indices:list, id_dictionary:dict):
    learner_id_fold = {
        'train': {idd:[] for idd in id_dictionary['index']},
        'validation': {}
    }
    for fold in folds:
        train = folds[fold]['train']
        validation = folds[fold]['validation']
        
        train = [oversampled_indices[idx] for idx in train]
        validation = [oversampled_indices[idx] for idx in validation]
        
        train = [id_dictionary['sequences'][idx]['learner_id'] for idx in train]
        validation = [id_dictionary['sequences'][idx]['learner_id'] for idx in validation]
        
        for lid in train:
            learner_id_fold['train'][lid].append(fold)
        for lid in validation:
            learner_id_fold['validation'][lid] = fold
    return learner_id_fold

# %%
def images_labels(addresses:list, local_addresses:list, label_map:dict, id_folds:dict):
    permutation = re.compile('^p([0-9]+)_')
    learner_id = re.compile('_l([A-z0-9]+)_t')
    task = re.compile('_t([0-9]+).')
    
    not_train = 0
    missing_perm = 0
    
    learners = []
    tasks = []
    folds = []
    ads = []
    labels = []
    for i, address in enumerate(addresses):
        try:
            p = permutation.findall(address)[0]
            l = learner_id.findall(address)[0]
            t = task.findall(address)[0]
            f = id_folds['validation'][l]

            ads.append(local_addresses[i])
            learners.append(l)
            tasks.append(t)
            folds.append(f)
            labels.append(label_map[p])
        except IndexError:
            missing_perm += 1
        except KeyError:
            not_train += 1
            
    print('There are {} missing perms and {} timelines who were too short'.format(missing_perm, not_train))
        
    return ads, learners, tasks, folds, labels

# %%
def plot_for_task(addresses:list, folds:list, tasks:list, task:int):
    indices = [i for i in range(len(tasks)) if tasks[i] == str(task)]
    ad = [addresses[idx] for idx in indices]
    fs = [folds[idx] for idx in indices]
    ipyplot.plot_class_tabs(ad, fs, max_imgs_per_tab=10, img_width=700)

# %%
def get_map(label_map:str) -> dict:
    if label_map == 'vector_labels':
        map_path = '../../data/experiment_keys/permutation_maps/vector_binary.yaml'
        
    with open(map_path) as fp:
        return yaml.load(fp, Loader=yaml.FullLoader)

# %% [markdown]
# # images

# %%
vector_map = get_map('vector_labels')
learner_id_fold = get_id_folds(folds, oversampled_indices, id_dictionary)
ads, learners, tasks, fs, labels = images_labels(addresses, local_addresses, vector_map['map'], learner_id_fold)
plot_for_task(ads, fs, tasks, 2)
# Out:
# There are 247 missing perms and 795 timelines who were too short
#     <style>
#         #ipyplot-html-viewer-toggle-W9eCkARzEUYZoirqYPAfQR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-W9eCkARzEUYZoirqYPAfQR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-W9eCkARzEUYZoirqYPAfQR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-W9eCkARzEUYZoirqYPAfQR:checked ~ #ipyplot-html-viewer-textarea-W9eCkARzEUYZoirqYPAfQR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-W9eCkARzEUYZoirqYPAfQR:checked + #ipyplot-html-viewer-label-W9eCkARzEUYZoirqYPAfQR:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-W9eCkARzEUYZoirqYPAfQR">
#         <label id="ipyplot-html-viewer-label-W9eCkARzEUYZoirqYPAfQR" for="ipyplot-html-viewer-toggle-W9eCkARzEUYZoirqYPAfQR">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-W9eCkARzEUYZoirqYPAfQR" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh {
#                 display: none;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh + label.ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh:checked + label.ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh ~ .tab {
#                 display: none
#             }
#     #tabKWceSzxFdLV6qFema6sxZm:checked ~ .tab.contentKWceSzxFdLV6qFema6sxZm,#tab9PESURkp9cJCttL7FBdxgV:checked ~ .tab.content9PESURkp9cJCttL7FBdxgV,#tabcGzCevHRiGiV72GvKok5GD:checked ~ .tab.contentcGzCevHRiGiV72GvKok5GD,#tabgi7Z8JJhXpdEe5j4unfkjS:checked ~ .tab.contentgi7Z8JJhXpdEe5j4unfkjS,#tab6QpdHbau8jyg9uDYpP8N3X:checked ~ .tab.content6QpdHbau8jyg9uDYpP8N3X,#tabWwoRuLKZkk5VqKvziaDYKW:checked ~ .tab.contentWwoRuLKZkk5VqKvziaDYKW,#tabMuyADCp9Ywb7aVbFshpsJc:checked ~ .tab.contentMuyADCp9Ywb7aVbFshpsJc,#tabBSZru4Qm9ixHAT79cE7vi7:checked ~ .tab.contentBSZru4Qm9ixHAT79cE7vi7,#tabQ589VjSCkGWYGajbCi3VAR:checked ~ .tab.contentQ589VjSCkGWYGajbCi3VAR,#tab3FQPnx3iS4vpp2hzCdTVx7:checked ~ .tab.content3FQPnx3iS4vpp2hzCdTVx7{ display: block; }</style><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabKWceSzxFdLV6qFema6sxZm" checked /><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabKWceSzxFdLV6qFema6sxZm">0</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab9PESURkp9cJCttL7FBdxgV"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab9PESURkp9cJCttL7FBdxgV">1</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabcGzCevHRiGiV72GvKok5GD"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabcGzCevHRiGiV72GvKok5GD">2</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabgi7Z8JJhXpdEe5j4unfkjS"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabgi7Z8JJhXpdEe5j4unfkjS">3</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab6QpdHbau8jyg9uDYpP8N3X"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab6QpdHbau8jyg9uDYpP8N3X">4</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabWwoRuLKZkk5VqKvziaDYKW"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabWwoRuLKZkk5VqKvziaDYKW">5</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabMuyADCp9Ywb7aVbFshpsJc"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabMuyADCp9Ywb7aVbFshpsJc">6</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabBSZru4Qm9ixHAT79cE7vi7"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabBSZru4Qm9ixHAT79cE7vi7">7</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabQ589VjSCkGWYGajbCi3VAR"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabQ589VjSCkGWYGajbCi3VAR">8</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab3FQPnx3iS4vpp2hzCdTVx7"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab3FQPnx3iS4vpp2hzCdTVx7">9</label><div class="tab contentKWceSzxFdLV6qFema6sxZm">
#         <style>
#         #ipyplot-imgs-container-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CZ7vKsf9cYeP6ffor7KxYu">
#     <div class="ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu">
#         <div id="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-SHQxEwixZ7yDvCsMJQiJFR" class="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: bre
# <div>
#         <style>
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh {
#                 display: none;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh + label.ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh:checked + label.ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh ~ .tab {
#                 display: none
#             }
#     #tabKWceSzxFdLV6qFema6sxZm:checked ~ .tab.contentKWceSzxFdLV6qFema6sxZm,#tab9PESURkp9cJCttL7FBdxgV:checked ~ .tab.content9PESURkp9cJCttL7FBdxgV,#tabcGzCevHRiGiV72GvKok5GD:checked ~ .tab.contentcGzCevHRiGiV72GvKok5GD,#tabgi7Z8JJhXpdEe5j4unfkjS:checked ~ .tab.contentgi7Z8JJhXpdEe5j4unfkjS,#tab6QpdHbau8jyg9uDYpP8N3X:checked ~ .tab.content6QpdHbau8jyg9uDYpP8N3X,#tabWwoRuLKZkk5VqKvziaDYKW:checked ~ .tab.contentWwoRuLKZkk5VqKvziaDYKW,#tabMuyADCp9Ywb7aVbFshpsJc:checked ~ .tab.contentMuyADCp9Ywb7aVbFshpsJc,#tabBSZru4Qm9ixHAT79cE7vi7:checked ~ .tab.contentBSZru4Qm9ixHAT79cE7vi7,#tabQ589VjSCkGWYGajbCi3VAR:checked ~ .tab.contentQ589VjSCkGWYGajbCi3VAR,#tab3FQPnx3iS4vpp2hzCdTVx7:checked ~ .tab.content3FQPnx3iS4vpp2hzCdTVx7{ display: block; }</style><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabKWceSzxFdLV6qFema6sxZm" checked /><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabKWceSzxFdLV6qFema6sxZm">0</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab9PESURkp9cJCttL7FBdxgV"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab9PESURkp9cJCttL7FBdxgV">1</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabcGzCevHRiGiV72GvKok5GD"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabcGzCevHRiGiV72GvKok5GD">2</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabgi7Z8JJhXpdEe5j4unfkjS"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabgi7Z8JJhXpdEe5j4unfkjS">3</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab6QpdHbau8jyg9uDYpP8N3X"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab6QpdHbau8jyg9uDYpP8N3X">4</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabWwoRuLKZkk5VqKvziaDYKW"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabWwoRuLKZkk5VqKvziaDYKW">5</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabMuyADCp9Ywb7aVbFshpsJc"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabMuyADCp9Ywb7aVbFshpsJc">6</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabBSZru4Qm9ixHAT79cE7vi7"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabBSZru4Qm9ixHAT79cE7vi7">7</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tabQ589VjSCkGWYGajbCi3VAR"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tabQ589VjSCkGWYGajbCi3VAR">8</label><input class="ipyplot-tab-TRiuUrZep6WtbYcFzw6dxh" type="radio" name="tabs-TRiuUrZep6WtbYcFzw6dxh" id="tab3FQPnx3iS4vpp2hzCdTVx7"/><label class="ipyplot-tab-label-TRiuUrZep6WtbYcFzw6dxh" for="tab3FQPnx3iS4vpp2hzCdTVx7">9</label><div class="tab contentKWceSzxFdLV6qFema6sxZm">
#         <style>
#         #ipyplot-imgs-container-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CZ7vKsf9cYeP6ffor7KxYu">
#     <div class="ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu">
#         <div id="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-SHQxEwixZ7yDvCsMJQiJFR" class="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p0213_luhbpoog9_t2.png</h4><img src="../../reports/timelines/colour timelines/p0213_luhbpoog9_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-SHQxEwixZ7yDvCsMJQiJFR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu">
#         <div id="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-ar7SsUqP7ZybXqdnTaS8Do" class="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">../../reports/timelines/colour timelines/p0321_lsuyrrcqe_t2.png</h4><img src="../../reports/timelines/colour timelines/p0321_lsuyrrcqe_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-ar7SsUqP7ZybXqdnTaS8Do">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CZ7vKsf9cYeP6ffor7KxYu">
#         <div id="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu-JBsRWfaQMqCTESJULHiTWH" class="ipyplot-content-div-CZ7vKsf9cYeP6ffor7KxYu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>

# %% [markdown]
# # Distribution of labels per fold

# %% [markdown]
# ## Stratification on label

# %%
def get_colour():
    palette = [
        '#b7094c', '#a01a58', '#892b64', '#723c70', '#5c4d7d', '#455e89', '#2e6f95', '#1780a1', '#0091ad',
    ]
    return np.random.choice(palette)

# %%
fold_labels = pd.DataFrame([fs, labels]).transpose()
fold_labels.columns = ['folds', 'labels']

label_map = vector_map['labels']
labs = [int(lab[0]) + int(lab[1]) + int(lab[2]) for lab in label_map]
labs = np.argsort(labs)
label_map = [label_map[idx] for idx in labs]

fold_labels = fold_labels[fold_labels['labels'].isin(labels)]

# %%
fold_map = fold_labels['folds'].unique()
fold_map.sort()
for fold in fold_map:
    fold_df = fold_labels[fold_labels['folds'] == fold]
    
    heights = []
    for lab in label_map:
        if lab in fold_df['labels'].unique():
            lb_df = fold_df[fold_df['labels'] == lab]
            h = len(lb_df) / len(fold_df)
            heights.append(h)
        else:
            heights.append(0)
            
    plt.figure(figsize=(12, 4))
    plt.bar(label_map, heights, color=get_colour(), alpha=0.4)
    plt.title('Label distribution for fold {}'.format(fold))
    plt.show()

# %%
pwd
# Out:
# '/Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/notebooks/8 - timelines'

# %%
cd ../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %%
with open(experiment_path + 'config.yaml', 'rb') as fp:
    config = pickle.load(fp)

# %%
config['id_dictionary']['sequences'][0]
# Out:
# {'path': '../data/sequenced_simulations/stateaction_secondslstm/p_2013_lidsvdphyjs_t2_sequenced.pkl',
#  'length': 78,
#  'learner_id': 'svdphyjs'}

# %%
with open(experiment_path + 'config.yaml', 'rb') as fp:
    config = pickle.load(fp)
    id_dictionary = config['id_dictionary']

# %%
with open('../data/post_test/rankings.pkl', 'rb') as fp:
    rankings = pickle.load(fp)
    id_rankings = {rankings.iloc[i]['username']: rankings.iloc[i]['ranking'] for i in range(len(rankings))}

# %%
id_rankings
# Out:
# {'bezdgyya': '0123',
#  'y7p64n6z': '3012',
#  '892r4czm': '2031',
#  'uhbpoog9': '0213',
#  'bed4zkv2': '1023',
#  'ytrbygud': '0231',
#  'vqebanqv': '2031',
#  'mwfdr4ys': '3120',
#  'r2e3h3tm': '2031',
#  '8ga2zn5h': '2031',
#  '3qwayak9': '3012',
#  'fh76v5qx': '0231',
#  '6tgyhcuh': '0321',
#  'd72hfax6': '3012',
#  'fryxwskq': '2130',
#  'favvtnnf': '3021',
#  'qvna6pyz': '0132',
#  'addf7f7d': '3012',
#  '9sgu2tbg': '0213',
#  'k7p5eryf': '2310',
#  'pesfpzbv': '3012',
#  'jpccnav5': '0321',
#  'xtnmv9qf': '2130',
#  'r78kg7d3': '1023',
#  'uqzxsym7': '3012',
#  '8jp62suc': '2013',
#  '63v3czy6': '0213',
#  '88kjzd8b': '0231',
#  '7hrf6cdu': '3012',
#  'vwfpuqaz': '3102',
#  '3w54b2bu': '2103',
#  's78drqcg': '3102',
#  '8rtwmb8t': '3012',
#  'uthx49rq': '2310',
#  'bjy2zpww': '0321',
#  'zy256ycq': '0123',
#  'fu6nsdhs': '2031',
#  'm3d89p29': '3210',
#  '5h9umyr6': '2031',
#  '4b4dkjuw': '0123',
#  '46bty2zg': '3012',
#  'z8hvrhwb': '3012',
#  'my6csh6m': '0321',
#  'krd7m9vb': '3120',
#  'yc3vmnuf': '1320',
#  '2ae6q3hw': '2031',
#  '2hr6mkdc': '3120',
#  '8nh4zvcp': '0213',
#  's2up6gmm': '0231',
#  '47ce49e4': '2013',
#  'fj5tdybn': '0231',
#  'y8qbtkmf': '2130',
#  'sr34qyfx': '3120',
#  'ntqpqkpq': '2130',
#  'r29wzm6f': '2130',
#  'zgs84jfy': '3201',
#  'dzakgq29': '3012',
#  'ybxahrra': '2103',
#  'x5sm9pfu': '2103',
#  'b72hbgvw': '2130',
#  'g43q3d94': '3201',
#  'vqumj3t3': '0231',
#  '4vuc8rr3': '3021',
#  'cwgvxrvx': '2130',
#  'rmd35un4': '2013',
#  '55yavcue': '3210',
#  '33asfz2u': '1320',
#  'rfand3tt': '2301',
#  'ew6cfr37': '0231',
#  'z8dtc572': '0321',
#  't7728bqp': '2301',
#  'tsvcrpeg': '0231',
#  'xngb9hff': '2013',
#  'gyerx2d9': '0123',
#  'wvxkvhne': '3012',
#  'o9ffsiwt': '0312',
#  'ecaf72fu': '3120',
#  'bf4iuomx': '0312',
#  'qsx2cc4b': '2031',
#  'kq2e6dgu': '3012',
#  'oikzz9af': '3012',
#  'xau6wapw': '1032',
#  'ac4q67z9': '2130',
#  'r2q9q35x': '0123',
#  'p2u7xw38': '3012',
#  'n6zakrku': '3012',
#  'padezf8m': '0312',
#  'amqnxthw': '2031',
#  'j9ukgkp5': '3012',
#  'szvqb37f': '3201',
#  'dnvedphf': '2301',
#  'chca7sdb': '3120',
#  'temu2736': '3120',
#  'v2kw3kup': '3012',
#  'mcjaj2aj': '3210',
#  'xuwyv9hz': '2103',
#  'h543nsc8': '2103',
#  'wxz98urt': '3012',
#  'qk6q49f4': '2103',
#  'r42kwnt7': '2103',
#  'jvxejtp9': '0231',
#  'vh8vedkw': '2310',
#  'm9u6p93a': '3021',
#  '4s7gthwf': '3201',
#  'nmgve3yy': '2130',
#  '3st3y5gc': '3120',
#  'fyf6ag5v': '3102',
#  'fm5rcvdy': '1230',
#  'wger3sfa': '2013',
#  'sjz2rptd': '0231',
#  'b2q8ay65': '2013',
#  'u96tpd55': '0312',
#  '9p9gwu88': '2031',
#  'pyamv67t': '3120',
#  'p6ut882m': '0231',
#  'egg8756y': '3012',
#  'eau7bsmq': '2031',
#  'zxp438xr': '3012',
#  'va43652k': '3012',
#  'p44vw7td': '0231',
#  'z5dzzgk5': '3210',
#  'baqyfz2h': '3120',
#  'mzjq6z9t': '0231',
#  'v9sra3j2': '0213',
#  '4ak6da99': '3120',
#  '5zqfzwjg': '3012',
#  'sz8qvgyv': '2103',
#  'xw9qt6r4': '0213',
#  '85pdk9mq': '0312',
#  'svdphyjs': '2013',
#  '982cf4dn': '3120',
#  '6rfakyp7': '2130',
#  '3kzp9bet': '3012',
#  '2ejxq2u8': '2301',
#  'qkeyp2rg': '0312',
#  'sm8sfpcg': '3021',
#  'eb9iv6v2': '3102',
#  'ssz3uyqn': '3201',
#  's8w65sm5': '1203',
#  '5a69aw4h': '3102',
#  'dbt5na3s': '0213',
#  'e3b96acv': '2013',
#  '5y535ct3': '2310',
#  '6bq62prp': '3120',
#  'ay2erc3c': '3120',
#  'r74r26kt': '0312',
#  'jwajupwj': '3120',
#  'j6nndaxp': '3102',
#  '4vtjgtja': '0123',
#  'araav4jr': '2130',
#  'xvsgn53d': '2310',
#  '7ygreyfc': '3012',
#  'nba9d6t2': '2310',
#  'smqjhu44': '0231',
#  'qpmzsb6t': '2013',
#  '8ethqmkd': '1302',
#  'upkt7qb4': '1203',
#  'xe7c36dk': '3012',
#  'ydws5xx9': '0231',
#  '3se7z466': '3210',
#  'akgpua6j': '3012',
#  '84nmc3df': '2301',
#  'nsj6k2rg': '2031',
#  'sx3vqc32': '2013',
#  '9aagpn4d': '2301',
#  'mwwddfvg': '3021',
#  'xj86wyup': '3120',
#  'hkvk9vt9': '0231',
#  'jkbx6axr': '2310',
#  'ujp9fgpn': '2031',
#  '5zrt4f8z': '2031',
#  'tzpqpfaa': '0213',
#  '2ep3hayy': '3012',
#  'e8zdytr2': '0213',
#  'hg7zc2sv': '0213',
#  '3xcaamq9': '3012',
#  '4k4dk9pu': '2031',
#  'fzagvhvf': '3120',
#  'y9tk3ysm': '3012',
#  'tzbaaz7e': '0312',
#  'sgsxmkfm': '0312',
#  'cjarhqn9': '0132',
#  '6ruh7enb': '0231',
#  '7fj2vydr': '2013',
#  'suyrrcqe': '0321',
#  'chm4sr6j': '0231',
#  'gvqh7qr2': '1032',
#  'zkrr45y5': '2013',
#  '4rhnvke9': '3120',
#  '7xhcecye': '3021',
#  'qsd9cb5e': '0312',
#  's7mdq5tk': '0231',
#  'pbxyuw7u': '3012',
#  'dk43m2pe': '0231',
#  'e22ppyf7': '0231',
#  'ur9sxzx7': '1032',
#  'aj47uhb9': '0312',
#  'cb6wcvyn': '2130',
#  'nmptx7nj': '3210',
#  'puzxz678': '3120',
#  '3gqs3sgc': '3120',
#  'tt5n8d2r': '0312',
#  '2crhmbq7': '3210',
#  'urwu33jd': '3210',
#  'n977pem4': '3120',
#  'qfu6r8c7': '0312',
#  'cb3z5rjs': '2103',
#  'dmdc53tx': '3012',
#  'fw2ajjmt': '2103',
#  'rg4fgfyh': '2103',
#  'srmr7pcp': '2130',
#  'uqven68r': '1032',
#  'u4zu9xxc': '3012',
#  'hrhu4yph': '2130',
#  'zbabnwym': '0312',
#  'xdxyjh8j': '3012',
#  '4e438nww': '3012',
#  'drccqhk4': '2130',
#  'nemddmx6': '2031',
#  'dubyutqd': '1203',
#  'wu7kdm6q': '0312',
#  '39htvmt5': '3021',
#  'sctj44cs': '3012',
#  'jnjd79vh': '3012',
#  'qqf6nsga': '2130',
#  'qevswkvj': '3012',
#  'xz56yha8': '0321',
#  'bebyve9b': '0231',
#  'pmd5dyu3': '3102',
#  'rwax4gk7': '1023',
#  'jcrv9m9j': '3120',
#  'jamrhf3h': '3102',
#  '552gbupp': '1032',
#  '5xuzjwdp': '3012',
#  'mkw5afyy': '1320',
#  'nw65tu6j': '3120',
#  'nfshnktq': '3012',
#  'eh9jq2bp': '3102',
#  'p6269reg': '0321',
#  'p6mkaa4e': '0213',
#  '4k4kc2k6': '2031',
#  'a3vdjxy9': '2031',
#  'nj859xxh': '2013',
#  'crak75dx': '2103',
#  'jhrkm85q': '2013',
#  '6j6u2yct': '3021',
#  '5es5yqs8': '0213',
#  'unkrat9w': '3021',
#  'beypwbck': '3012',
#  'wnurkn96': '2103',
#  'jydsy777': '3102',
#  'uamuwrx2': '3120',
#  '9qvk2wew': '2130',
#  'uhq3p7yr': '3012',
#  '9p4h3zdx': '0321',
#  'v5gwycag': '0123',
#  'wyj76ntd': '2103',
#  '4jchqv4d': '1302',
#  'u6c3cp6c': '2130',
#  'm4zvafhs': '0213',
#  'u25vrfyy': '3102',
#  'c9dj36r7': '3012',
#  'fy29cvrj': '3120',
#  'st3mf78y': '0231',
#  '5f4q4ng5': '3021',
#  'f54jkrsw': '3012',
#  '6z7nfy2j': '2013',
#  'rdy7sx9b': '0312',
#  '5j7hdews': '3120',
#  'uad7cmhv': '3210',
#  'hrxpbujy': '2130',
#  'wbdyh5vk': '2031',
#  'wktpsvp8': '2103',
#  '22wyn9xy': '3210',
#  '3vsn2h9f': '2031',
#  '9wdm7zue': '3012',
#  '5m3ka2m2': '3120',
#  '9yv4uxn3': '2031',
#  'vjr7tshm': '0312',
#  'c87kgzbr': '3012',
#  'qjfn2j8z': '1230',
#  'h4hxzc6s': '3201',
#  'rdbqasqa': '1320',
#  'yez72a8b': '2103',
#  'gu7jpyum': '3201',
#  'x844md8u': '3201',
#  'a57jkjgv': '2130',
#  'qn4qjrvd': '2130',
#  'urxv4evt': '2130',
#  'sgdgynxy': '0231',
#  'uagxrke6': '2103',
#  's9prcjfd': '3012',
#  'vckta85p': '2130',
#  '63xqh9t5': '3102',
#  'upp6pqmx': '3120',
#  'yxf7q6ap': '2031',
#  'wpszzhxa': '3120',
#  'xpyjyx4m': '3120',
#  'w9w2hw35': '2130',
#  'pggnv6xw': '2130',
#  'qner25zp': '2031',
#  'mnhmyuhb': '2031',
#  'cp7mfn24': '3210',
#  't3dwkezr': '3120',
#  'npkrjraq': '2031',
#  'zs35fg8g': '3012',
#  'aurjfgnn': '0213',
#  'nrxpa2ac': '0231',
#  'a6t5p3sb': '0321',
#  '6tg95rzr': '0231',
#  'h75kp27p': '2031',
#  'v2cxb3a5': '3021',
#  'kg43uepa': '0231',
#  '4aaspwgs': '2103',
#  'v5w2e3zw': '0231',
#  's47edumx': '3102',
#  'knun7j9s': '2031',
#  '3s6pz8qy': '1230',
#  'b8g49nvw': '3120',
#  'dq4zzkyt': '0312',
#  'ryfqnvfh': '2130',
#  'uswb2jez': '2031',
#  'xsxkdf7k': '0213',
#  'neuwx57b': '3102',
#  '26z3wbqz': '2130',
#  'jx3yyy26': '3120',
#  'g4xpwwac': '1023',
#  '2cetp8yc': '2130',
#  '6cs3annc': '1302',
#  'npatrq7r': '3021',
#  '7xwv3xfe': '1320',
#  'xcmyd5r5': '3021',
#  '7ck7mq6a': '0312',
#  '2xh9zuvc': '0213',
#  'qdp9ant4': '0231',
#  'rrykpeqz': '0213',
#  'g6z8qykr': '3012',
#  'prr8qsns': '0321',
#  'h9t9mxtx': '1023',
#  'caq55qe8': '3012',
#  'vhsgf3xa': '0321',
#  'knbr3qun': '2031',
#  '7g36g5tz': '0312',
#  'bqmcqxyx': '0321',
#  'fs32fqe3': '3012',
#  '9xc2v9vu': '2031',
#  'xmh5qd3z': '0321',
#  'gpq26qq9': '3120',
#  '5pt9tpaj': '0321',
#  'gc663sap': '3120',
#  '4rjjdez9': '0321',
#  'rjx9d3gf': '3012',
#  '7zjqat99': '0321',
#  'm4frzqy6': '3021',
#  'jwntt96k': '0213',
#  'q4z45p85': '0231',
#  'p5t7d3sb': '0231',
#  'evqzjs5p': '0231',
#  'tcnba4ca': '3201',
#  '4bu2rkv3': '0213',
#  'd7777ske': '3012',
#  'mhek2323': '0213',
#  'e93na59g': '2031',
#  'ujpk3gf4': '3012',
#  'fddsxudu': '1320',
#  '76wvaew4': '3012',
#  'z6ur4njh': '3210',
#  '6fkbh35u': '3120',
#  '9pjrsbth': '3102',
#  '26mtbtye': '3021',
#  'ecy9k833': '2031',
#  'uqw5vh3j': '2031',
#  'wwj8nq34': '3012',
#  'tvtbbfhg': '3120',
#  '9hdhrrat': '0312',
#  'edmrufua': '2310',
#  'gk7r7cee': '3021',
#  'vbym9sms': '0312',
#  'hf8uz5t3': '3210',
#  'bje92qp8': '0213',
#  'mp2aa258': '0123',
#  '4zsmj6s3': '3012',
#  'wguewwkp': '3210',
#  'uenn9vgu': '3021',
#  'kq4eymtu': '2130',
#  'bswtap2v': '2031',
#  '9rked2x5': '3012',
#  'phupma28': '0213',
#  '7t9zwtmr': '3102',
#  'n3977erj': '3012',
#  'x3ykresy': '1230',
#  'v5wcy2tt': '3012',
#  '7e4jt9hn': '2103',
#  '6uakv8nx': '3210',
#  '8pskk9tr': '0231',
#  '5vvwhzqs': '3012',
#  'eqdntxer': '2310',
#  'rgeb7wr9': '2031',
#  '6h5vmwys': '0123',
#  'ht865nws': '1320',
#  'sh6tu9g2': '2013',
#  'sp82v9ds': '0231',
#  'm35ub35g': '2013',
#  'w7asnymz': '0213',
#  'j9qgkaej': '3120',
#  'rve4n5nv': '3210',
#  'djnysnd6': '2031',
#  'z4nrhe2e': '3120',
#  'zgyc948n': '0213',
#  'cdq4drkk': '2013',
#  'w25mph3c': '0231',
#  'tsrnkj8w': '0213',
#  '2xjmtbvz': '2031',
#  '3e3k2662': '2031',
#  'k8x4ru7k': '0321',
#  'm749z8u9': '2031',
#  'bg7x3db2': '2013',
#  '43e33t3h': '2031',
#  'ky8kttpv': '0213',
#  '9bp6yz7m': '0231',
#  'ke6msbfr': '3120',
#  't6rjyw6s': '2031'}
