# %%
import os
import pickle

import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

# %%
cd ../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %% [markdown]
# # Functions

# %%
def plot_folds(pathname, title, val_metric='val_categorical_crossentropy'):
    files = os.listdir(pathname)
    files = [file for file in files if file.endswith('.csv')]
    files.sort()
    plt.figure(figsize=(12, 4))
    for file in files:
        model = pd.read_csv(pathname + file, sep=';')
        plt.plot(model['epoch'], model[val_metric], label=file[0:2])
    title = 'Fold result for ' + title + ' [' + val_metric + ']'
    plt.ylim([0.5, 0.75])
    plt.title(title)
    plt.legend()
    plt.show()
    
def plot_shaded_folds(pathname, title, val_metric='val_categorical_crossentropy'):
    files = os.listdir(pathname)
    files = [file for file in files if file.endswith('.csv')]
    files.sort()
    
    metrics = []
    val_metrics = []
    
    plt.figure(figsize=(12, 8))
    for file in files:
        model = pd.read_csv(pathname + file, sep=';')
        metrics.append(list(model[val_metric]))
        val_metrics.append(list(model['val_' + val_metric]))
        
    minimums = np.min([(len(metr)) for metr in metrics])
    metrics = [metri[:minimums] for metri in metrics]
    means = np.mean(metrics, axis=0)
    stds = np.std(metrics, axis=0)
    
    plt.plot(model['epoch'], means, color='#abc4ff')
    plt.fill_between(model['epoch'], means - stds, means + stds, alpha=0.3, color='#abc4ff', label='train')

    minimums = np.min([(len(metr)) for metr in val_metrics])
    val_metrics = [metri[:minimums] for metri in val_metrics]
    means = np.mean(val_metrics, axis=0)
    stds = np.std(val_metrics, axis=0)
    
    plt.plot(model['epoch'], means, color='#ff5c8a')
    plt.fill_between(model['epoch'], means - stds, means + stds, alpha=0.3, color='#ff5c8a', label='validation')
    
    title = 'Fold result for ' + title + ' [' + val_metric + ']'
    plt.ylim([0, 2])
    plt.legend()
    plt.title(title)
    plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# ## Encoded LSTM

# %% [markdown]
# ### 2 layers

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 100
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_encodedlstm_12/binconcepts/lstm/raw_full/2021_12_10_0/0/logger/ctBiLSTM_nlayers2_ncells32_drop02_optimadam_lossauc_bs16_ep100long short term memory/'
plot_shaded_folds(encoded, 'padded flat encoding - batchsize 16 - 2 layers', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded flat encoding - batchsize 16 - 2 layers', 'auc')

# %% [markdown]
# ### 4 layers

# %%
"""
Params: 
    - batch size: 16
    - layers: 4
    - ncells: 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 100
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_encodedlstm_12/binconcepts/lstm/raw_full/2021_12_10_1/0/logger/ctBiLSTM_nlayers4_ncells32_drop02_optimadam_lossauc_bs16_ep100long short term memory/'
plot_shaded_folds(encoded, 'padded flat encoding - batchsize 16 - 4 layers', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded flat encoding - batchsize 16 - 4 layers', 'auc')

# %% [markdown]
# ## Seconds

# %%
"""
Params: 
    - batch size: 32
    - layers: 2
    - ncells: 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 100
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_10_0/0/logger/ctBiLSTM_nlayers2_ncells32_drop02_optimadam_lossauc_bs32_ep100long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 32', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 32', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 100
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_10_1/0/logger/ctBiLSTM_nlayers2_ncells32_drop02_optimadam_lossauc_bs16_ep100long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 16, 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_12_0/0/logger/ctBiLSTM_nlayers2_ncells[16, 32]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 8, 16, 8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_12_1/0/logger/ctBiLSTM_nlayers3_ncells[8, 16, 8]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 16, 32
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_12_2/0/logger/ctBiLSTM_nlayers2_ncells[16, 32]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 8, 16, 8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_12_3/0/logger/ctBiLSTM_nlayers3_ncells[8, 16, 8]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8, 16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.02
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_12_4/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop002_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_0/0/logger/ctBiLSTM_nlayers1_ncells[16, 16]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_1/0/logger/ctBiLSTM_nlayers1_ncells[16, 16]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_2/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.5
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_3/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop05_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 4.8.4
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.5
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_4/0/logger/ctBiLSTM_nlayers3_ncells[4, 8, 4]_drop05_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_0_0/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 
    - ncells: 8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_1_0/0/logger/ctBiLSTM_nlayers1_ncells[8, 8]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 4.8.4
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_2_0/0/logger/ctBiLSTM_nlayers3_ncells[4, 8, 4]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 4.8.4
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_3_0/0/logger/ctBiLSTM_nlayers3_ncells[4, 8, 4]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 8.8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_4_0/0/logger/ctBiLSTM_nlayers1_ncells[8, 8]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 8.8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_5/0/logger/ctBiLSTM_nlayers1_ncells[8, 8]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

0

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 8
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_6/0/logger/ctBiLSTM_nlayers1_ncells[8]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

1
# Out:
# 0

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_7/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

5
# Out:
# 1

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 4.8.4
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_8/0/logger/ctBiLSTM_nlayers3_ncells[4, 8, 4]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

7
# Out:
# 5

# %%
"""
Params: 
    - batch size: 16
    - layers: 3
    - ncells: 4.8.4
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_9/0/logger/ctBiLSTM_nlayers3_ncells[4, 8, 4]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

8
# Out:
# 7

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_10/0/logger/ctBiLSTM_nlayers1_ncells[16]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

2
# Out:
# 8

# %%
"""
Params: 
    - batch size: 16
    - layers: 1
    - ncells: 16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0.2
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_11/0/logger/ctBiLSTM_nlayers1_ncells[16]_drop02_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

3
# Out:
# 2

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_12/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

4
# Out:
# 3

# %%
"""
Params: 
    - batch size: 16
    - layers: 2
    - ncells: 8.16
    - optimiser: adam
    - Cell type: BiLSTM
    - epochs: 200
    - Dropout: 0
    - features: wl as between 500 and 564
"""
encoded = '../experiments/incremental/stateaction_secondslstm_12/binconcepts/lstm/raw_full/2021_12_13_13/0/logger/ctBiLSTM_nlayers2_ncells[8, 16]_drop00_optimadam_lossauc_bs16_ep200long short term memory/'
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'categorical_crossentropy')
plot_shaded_folds(encoded, 'padded seconds encoding - batchsize 16', 'auc')

4
