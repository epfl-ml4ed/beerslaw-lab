# %% [markdown]
# In this notebook, I test the loading functions for checkpoint models, and create a small script to rename correctly the files (in previous versions)

# %%
import os
import tensorflow as tf

# %%
experiment = 'nested/lstm'
experiment_path = '../../experiments/{}'.format(experiment)

# %%
model = [x for x in model_paths if '.pb' in x]

# %%
model
# Out:
# ['../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/4/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/language_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/field_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/field_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
# ...
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/3/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/yl_colourbreak/binconcepts/lstm/raw_full/2022_01_24_0/2/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f3_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f7_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f4_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f5_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f-1_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f2/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f3/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f4/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f1/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/models/lstm_f0/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f2_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f6_model_checkpoint/saved_model.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/keras_metadata.pb',
#  '../../experiments/nested/lstm/year_simplestate/binconcepts/lstm/raw_full/2022_01_23_0/1/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f8_model_checkpoint/saved_model.pb',
#  ...]

# %%
# renaming
keras_path = '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/'
checkpoint_paths = []
for (dirpath, dirnames, filenames) in os.walk(keras_path):
    files = [os.path.join(dirpath, file) for file in filenames]
    checkpoint_paths.extend(files)

# %%
for path in checkpoint_paths:
    new_path = path.replace('variables/variables.', 'variables/variables/cp.ckpt.')
    new_folder = '/'.join(new_path.split('/')[:-1])
    os.makedirs(new_folder, exist_ok=True)
    os.rename(path, new_path)

# %%
another_strategy = tf.distribute.OneDeviceStrategy("/cpu:0")
keras_path = '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/'
with another_strategy.scope():
    restored_keras_model_ds = tf.keras.models.load_model(keras_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jy/0pp1md9x1358dt8g8k69srhr0000gp/T/ipykernel_51569/1024290196.py in <module>
#       2 keras_path = '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f9_model_checkpoint/'
#       3 with another_strategy.scope():
# ----> 4     restored_keras_model_ds = tf.keras.models.load_model(keras_path)
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/keras/engine/base_layer.py in from_config(cls, config)
#     782         A layer instance.
#     783     """
# --> 784     return cls(**config)
#     785
#     786   def compute_output_shape(self, input_shape):
#
# TypeError: __init__() got an unexpected keyword argument 'reduction'

# %%
keras_path = '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/'
loaded = tf.saved_model.load(keras_path)
# Out:
# 2022-01-28 17:22:41.606760: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond/while' has 13 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# 2022-01-28 17:22:41.623816: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond' has 4 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# 2022-01-28 17:22:41.653995: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond/while' has 13 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# 2022-01-28 17:22:41.780597: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond' has 4 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# 2022-01-28 17:22:42.285758: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond/while' has 13 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# 2022-01-28 17:22:42.308395: W tensorflow/core/common_runtime/graph_constructor.cc:803] Node 'cond' has 4 outputs but the _output_shapes attribute specifies shapes for 46 outputs. Output shapes may be inaccurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/training/py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      95   try:
# ---> 96     return CheckpointReader(compat.as_bytes(filepattern))
#      97   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/variables/variables
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load_internal(export_dir, tags, options, loader_cls, filters)
#     937       try:
# --> 938         loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     939                             ckpt_options, options, filters)
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     165     if not save_options.experimental_skip_checkpoint:
# --> 166       self._restore_checkpoint()
#     167     for node in self._nodes:
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in _restore_checkpoint(self)
#     493     else:
# --> 494       load_status = saver.restore(variables_path, self._checkpoint_options)
#     495       load_status.assert_existing_objects_matched()
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in restore(self, save_path, options)
#    1321       return InitializationOnlyStatus(self._graph_view, ops.uid())
# -> 1322     reader = py_checkpoint_reader.NewCheckpointReader(save_path)
#    1323     graph_building = not context.executing_eagerly()
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/training/py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      99   except RuntimeError as e:
# --> 100     error_translator(e)
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/variables/variables
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jy/0pp1md9x1358dt8g8k69srhr0000gp/T/ipykernel_53481/3525832511.py in <module>
#       1 keras_path = '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/'
# ----> 2 loaded = tf.saved_model.load(keras_path)
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load(export_dir, tags, options)
#     898     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     899   """
# --> 900   result = load_internal(export_dir, tags, options)["root"]
#     901   return result
#     902
#
# /opt/anaconda3/envs/PhetGPU/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load_internal(export_dir, tags, options, loader_cls, filters)
#     939                             ckpt_options, options, filters)
#     940       except errors.NotFoundError as err:
# --> 941         raise FileNotFoundError(
#     942             str(err) + "\n You may be trying to load on a different device "
#     943             "from the computational device. Consider setting the "
#
# FileNotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/variables/variables
#  You may be trying to load on a different device from the computational device. Consider setting the `experimental_io_device` option in `tf.saved_model.LoadOptions` to the io_device such as '/job:localhost'.

# %%
keras_path
# Out:
# '../../experiments/nested/lstm/language_colourbreak/binconcepts/lstm/raw_full/2022_01_23_0/0/logger/ctGRU_nlayers1_ncells[32]_drop02_optimadam_lossauc_bs16_ep50lstm/f0_model_checkpoint/'

# %%
import re

# %%
outer_fold_re = re.compile('.*([0-9]+)/logger')
outer_fold = outer_fold_re.findall(keras_path)[0]

inner_fold_re = re.compile('.*f([0-9]+)_model_checkpoint/')
