# %%
# %load_ext autoreload

# %%
cd ../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %%
import os
import pickle
import yaml
import numpy as np
import pandas as pd
import ipyplot

from ml import load_tf_models as model_loader
from labels.xval_plotter import XvalLabelPlotter

# %% [markdown]
# # Functions

# %%
with open('./configs/labelconcat_config.yaml', 'r') as f:
        settings = yaml.load(f, Loader=yaml.FullLoader)
        settings['experiment']['name'] = 'real_nested/baselines'
xval_plotter = XvalLabelPlotter(settings)

with open('../data/experiment_keys/permutation_maps/vector_binary.yaml', 'rb') as fp:
    label_map = yaml.load(fp, Loader=yaml.FullLoader)

# %%
def get_pngaddresses(addresses, df):
    ids = list(df.index)
    adds = []
    for iid in ids:
        adds = adds + ['./colour timelines/' + t for t in addresses if iid in t and '_t2.' in t]
    return adds
    

def get_highlow(experiment, xval_plotter):
    summary_df = xval_plotter.get_summary_df(experiment)

    summary_df['vector_labels'] = summary_df['permutation'].apply(lambda x: label_map['map'][x])
    summary_df['pos_proba'] = summary_df['probas'].apply(lambda x: x[1])
    
    high = summary_df[summary_df['vector_labels'] == '111']
    high_bad = high[high['pos_proba'] < 0.2]
    high_good = high[high['pos_proba'] > 0.8]

    low = summary_df[summary_df['vector_labels'] == '000']
    low_bad = low[low['pos_proba'] > 0.8]
    low_good = low[low['pos_proba'] < 0.2]

    print(
        'There are {} high performers that are predicted as low performers, and {} low performers that are predicted as high performers'
    .format(len(high_bad), len(low_bad)))
    
    timeline_folder = '../notebooks/5 - training/colour timelines/'
    timelines = os.listdir(timeline_folder)
    timelines = [t for t in timelines if t.endswith('.png')]
    
    hb_addresses = get_pngaddresses(timelines, high_bad)
    hg_addresses = get_pngaddresses(timelines, high_good)

    lb_addresses = get_pngaddresses(timelines, low_bad)
    lg_addresses = get_pngaddresses(timelines, low_good)
    
    # high ipyplot
    hb_labels = ['low (wrong)' for _ in hb_addresses]
    hg_labels = ['high (good)' for _ in hg_addresses]

    high_addresses = hb_addresses + hg_addresses 
    high_labels = hb_labels + hg_labels
    
    
    # low ipyplot
    lb_labels = ['high (wrong)' for _ in lb_addresses]
    lg_labels = ['low (good)' for _ in lg_addresses]
    low_addresses = lb_addresses + lg_addresses
    low_labels = lb_labels + lg_labels
    
    # high predicted low and low predicted low
    pred_low_labels = ['high (pred low)' for _ in hb_addresses] + ['low (pred low)' for _ in lg_addresses]
    pred_low_addresses = [adr for adr in hb_addresses] + [adr for adr in lg_addresses]
    
    # high predicted high and low predicted high
    pred_high_labels = ['high (pred high)' for _ in hg_addresses] + ['low (pred high)' for _ in lb_addresses]
    pred_high_addresses = [adr for adr in hg_addresses] + [adr for adr in lb_addresses]

    
    plot_data = {
        'high': {
            'addresses': high_addresses,
            'labels': high_labels
        },
        'low': {
            'addresses': low_addresses,
            'labels': low_labels
        },
        'pred_high:': {
            'addresses': pred_high_addresses,
            'labels': pred_high_labels
        },
        'pred_low': {
            'addresses': pred_low_addresses,
            'labels': pred_low_labels
        }
    }
    
    return plot_data

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Simple state

# %%
experiment = '../experiments/real_nested/baselines/simplestate_secondslstm/binconcepts/lstm/raw_full/2022_01_28_0/'
plot_data = get_highlow(experiment, xval_plotter)
# Out:
# ../experiments/real_nested/baselines/simplestate_secondslstm/binconcepts/lstm/raw_full/2022_01_28_0/config.yaml
# There are 2 high performers that are predicted as low performers, and 8 low performers that are predicted as high performers

# %%
cd ../notebooks/5 - training
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/notebooks/5 - training

# %%
ipyplot.plot_class_tabs(plot_data['high']['addresses'], plot_data['high']['labels'], img_width=1000)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jwHoxsW7TngWW5EUv9pdzy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jwHoxsW7TngWW5EUv9pdzy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jwHoxsW7TngWW5EUv9pdzy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jwHoxsW7TngWW5EUv9pdzy:checked ~ #ipyplot-html-viewer-textarea-jwHoxsW7TngWW5EUv9pdzy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jwHoxsW7TngWW5EUv9pdzy:checked + #ipyplot-html-viewer-label-jwHoxsW7TngWW5EUv9pdzy:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jwHoxsW7TngWW5EUv9pdzy">
#         <label id="ipyplot-html-viewer-label-jwHoxsW7TngWW5EUv9pdzy" for="ipyplot-html-viewer-toggle-jwHoxsW7TngWW5EUv9pdzy">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jwHoxsW7TngWW5EUv9pdzy" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy {
#                 display: none;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy + label.ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy:checked + label.ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy ~ .tab {
#                 display: none
#             }
#     #tabbdv7rmftMHAgqVtbjEWCxD:checked ~ .tab.contentbdv7rmftMHAgqVtbjEWCxD,#tab9AkGwda3XEFi9ouBx9oWF7:checked ~ .tab.content9AkGwda3XEFi9ouBx9oWF7{ display: block; }</style><input class="ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy" type="radio" name="tabs-BvkZxXu6jWVV4Zzwzyigwy" id="tabbdv7rmftMHAgqVtbjEWCxD" checked /><label class="ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy" for="tabbdv7rmftMHAgqVtbjEWCxD">high (good)</label><input class="ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy" type="radio" name="tabs-BvkZxXu6jWVV4Zzwzyigwy" id="tab9AkGwda3XEFi9ouBx9oWF7"/><label class="ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy" for="tab9AkGwda3XEFi9ouBx9oWF7">low (wrong)</label><div class="tab contentbdv7rmftMHAgqVtbjEWCxD">
#         <style>
#         #ipyplot-imgs-container-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cwR9c6igwGZKHqrrgpaRQX">
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-RmYQ9yMWSEYd7t4dZxEZPU" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l3vsn2h9f_t2.png</h4><img src="./colour timelines/p2031_l3vsn2h9f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-RmYQ9yMWSEYd7t4dZxEZPU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Vb3YKvisK6YR7TBgEfrzLD" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_leau7bsmq_t2.png</h4><img src="./colour timelines/p2031_leau7bsmq_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Vb3YKvisK6YR7TBgEfrzLD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-NprnUp6Rk7amPJkq4Sv28b" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l5zrt4f8z_t2.png</h4><img src="./colour timelines/p2031_l5zrt4f8z_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-NprnUp6Rk7amPJkq4Sv28b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-oFu8EcRLhA2uoHt4hBWkPL" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wr
# <div>
#         <style>
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy {
#                 display: none;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy + label.ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy:checked + label.ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy ~ .tab {
#                 display: none
#             }
#     #tabbdv7rmftMHAgqVtbjEWCxD:checked ~ .tab.contentbdv7rmftMHAgqVtbjEWCxD,#tab9AkGwda3XEFi9ouBx9oWF7:checked ~ .tab.content9AkGwda3XEFi9ouBx9oWF7{ display: block; }</style><input class="ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy" type="radio" name="tabs-BvkZxXu6jWVV4Zzwzyigwy" id="tabbdv7rmftMHAgqVtbjEWCxD" checked /><label class="ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy" for="tabbdv7rmftMHAgqVtbjEWCxD">high (good)</label><input class="ipyplot-tab-BvkZxXu6jWVV4Zzwzyigwy" type="radio" name="tabs-BvkZxXu6jWVV4Zzwzyigwy" id="tab9AkGwda3XEFi9ouBx9oWF7"/><label class="ipyplot-tab-label-BvkZxXu6jWVV4Zzwzyigwy" for="tab9AkGwda3XEFi9ouBx9oWF7">low (wrong)</label><div class="tab contentbdv7rmftMHAgqVtbjEWCxD">
#         <style>
#         #ipyplot-imgs-container-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cwR9c6igwGZKHqrrgpaRQX">
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-RmYQ9yMWSEYd7t4dZxEZPU" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l3vsn2h9f_t2.png</h4><img src="./colour timelines/p2031_l3vsn2h9f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-RmYQ9yMWSEYd7t4dZxEZPU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Vb3YKvisK6YR7TBgEfrzLD" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_leau7bsmq_t2.png</h4><img src="./colour timelines/p2031_leau7bsmq_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Vb3YKvisK6YR7TBgEfrzLD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-NprnUp6Rk7amPJkq4Sv28b" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l5zrt4f8z_t2.png</h4><img src="./colour timelines/p2031_l5zrt4f8z_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-NprnUp6Rk7amPJkq4Sv28b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-oFu8EcRLhA2uoHt4hBWkPL" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_lrgeb7wr9_t2.png</h4><img src="./colour timelines/p2031_lrgeb7wr9_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-oFu8EcRLhA2uoHt4hBWkPL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Bt2RN84wdg4oz33jpriw85" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l4k4kc2k6_t2.png</h4><img src="./colour timelines/p2031_l4k4kc2k6_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-Bt2RN84wdg4oz33jpriw85">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cwR9c6igwGZKHqrrgpaRQX">
#         <div id="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX-m3CjHZsWr4X8o7EVYU8o23" class="ipyplot-content-div-cwR9c6igwGZKHqrrgpaRQX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%

# %%
ipyplot.plot_class_tabs(plot_data['low']['addresses'], plot_data['low']['labels'], img_width=1000)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2B77RS9SLQGiGzxXqhEjdf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2B77RS9SLQGiGzxXqhEjdf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2B77RS9SLQGiGzxXqhEjdf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2B77RS9SLQGiGzxXqhEjdf:checked ~ #ipyplot-html-viewer-textarea-2B77RS9SLQGiGzxXqhEjdf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2B77RS9SLQGiGzxXqhEjdf:checked + #ipyplot-html-viewer-label-2B77RS9SLQGiGzxXqhEjdf:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-2B77RS9SLQGiGzxXqhEjdf">
#         <label id="ipyplot-html-viewer-label-2B77RS9SLQGiGzxXqhEjdf" for="ipyplot-html-viewer-toggle-2B77RS9SLQGiGzxXqhEjdf">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-2B77RS9SLQGiGzxXqhEjdf" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT {
#                 display: none;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT + label.ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT:checked + label.ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT ~ .tab {
#                 display: none
#             }
#     #taberW63Cxfv7tzPJoMqxwRDU:checked ~ .tab.contenterW63Cxfv7tzPJoMqxwRDU,#tabma4G9c4qmy3kxPX7YpfXpb:checked ~ .tab.contentma4G9c4qmy3kxPX7YpfXpb{ display: block; }</style><input class="ipyplot-tab-XPRKM5via2bxxS8erqDdtT" type="radio" name="tabs-XPRKM5via2bxxS8erqDdtT" id="taberW63Cxfv7tzPJoMqxwRDU" checked /><label class="ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT" for="taberW63Cxfv7tzPJoMqxwRDU">high (wrong)</label><input class="ipyplot-tab-XPRKM5via2bxxS8erqDdtT" type="radio" name="tabs-XPRKM5via2bxxS8erqDdtT" id="tabma4G9c4qmy3kxPX7YpfXpb"/><label class="ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT" for="tabma4G9c4qmy3kxPX7YpfXpb">low (good)</label><div class="tab contenterW63Cxfv7tzPJoMqxwRDU">
#         <style>
#         #ipyplot-imgs-container-div-6YThwafArfiDTnA5HSjmVo {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-6YThwafArfiDTnA5HSjmVo">
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-X9z5UudpaJhy9fTg54qGH4" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p0312_lqsd9cb5e_t2.png</h4><img src="./colour timelines/p0312_lqsd9cb5e_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-X9z5UudpaJhy9fTg54qGH4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-YiAEmAtZ9Cxdov2xweBz9c" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2103_lwktpsvp8_t2.png</h4><img src="./colour timelines/p2103_lwktpsvp8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-YiAEmAtZ9Cxdov2xweBz9c">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-NmjqLXomXxMN9ScodhUGSb" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3021_l7xhcecye_t2.png</h4><img src="./colour timelines/p3021_l7xhcecye_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-NmjqLXomXxMN9ScodhUGSb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-o9GRdDygADBFp2AMp72Vuc" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wr
# <div>
#         <style>
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT {
#                 display: none;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT + label.ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT:checked + label.ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-XPRKM5via2bxxS8erqDdtT ~ .tab {
#                 display: none
#             }
#     #taberW63Cxfv7tzPJoMqxwRDU:checked ~ .tab.contenterW63Cxfv7tzPJoMqxwRDU,#tabma4G9c4qmy3kxPX7YpfXpb:checked ~ .tab.contentma4G9c4qmy3kxPX7YpfXpb{ display: block; }</style><input class="ipyplot-tab-XPRKM5via2bxxS8erqDdtT" type="radio" name="tabs-XPRKM5via2bxxS8erqDdtT" id="taberW63Cxfv7tzPJoMqxwRDU" checked /><label class="ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT" for="taberW63Cxfv7tzPJoMqxwRDU">high (wrong)</label><input class="ipyplot-tab-XPRKM5via2bxxS8erqDdtT" type="radio" name="tabs-XPRKM5via2bxxS8erqDdtT" id="tabma4G9c4qmy3kxPX7YpfXpb"/><label class="ipyplot-tab-label-XPRKM5via2bxxS8erqDdtT" for="tabma4G9c4qmy3kxPX7YpfXpb">low (good)</label><div class="tab contenterW63Cxfv7tzPJoMqxwRDU">
#         <style>
#         #ipyplot-imgs-container-div-6YThwafArfiDTnA5HSjmVo {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-6YThwafArfiDTnA5HSjmVo span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-6YThwafArfiDTnA5HSjmVo]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-6YThwafArfiDTnA5HSjmVo">
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-X9z5UudpaJhy9fTg54qGH4" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p0312_lqsd9cb5e_t2.png</h4><img src="./colour timelines/p0312_lqsd9cb5e_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-X9z5UudpaJhy9fTg54qGH4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-YiAEmAtZ9Cxdov2xweBz9c" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2103_lwktpsvp8_t2.png</h4><img src="./colour timelines/p2103_lwktpsvp8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-YiAEmAtZ9Cxdov2xweBz9c">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-NmjqLXomXxMN9ScodhUGSb" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3021_l7xhcecye_t2.png</h4><img src="./colour timelines/p3021_l7xhcecye_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-NmjqLXomXxMN9ScodhUGSb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-o9GRdDygADBFp2AMp72Vuc" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3201_lszvqb37f_t2.png</h4><img src="./colour timelines/p3201_lszvqb37f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-o9GRdDygADBFp2AMp72Vuc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-eW9oGcwEao5ooi3mQSJxkh" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2301_l84nmc3df_t2.png</h4><img src="./colour timelines/p2301_l84nmc3df_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-eW9oGcwEao5ooi3mQSJxkh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6YThwafArfiDTnA5HSjmVo">
#         <div id="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo-AUi3rW6RmE2TVy2Dz8xgDz" class="ipyplot-content-div-6YThwafArfiDTnA5HSjmVo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%

# %% [markdown]
# ## Field Simple state

# %%
experiment = '/Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/experiments/real_nested/demographics/field_simplestate/binconcepts/lstm/raw_full/2022_01_30_0'

# %%
cd ../../src
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/src

# %%
experiment = '../experiments/real_nested/baselines/simplestate_secondslstm/binconcepts/lstm/raw_full/2022_01_28_0/'
plot_data = get_highlow(experiment, xval_plotter)
# Out:
# ../experiments/real_nested/baselines/simplestate_secondslstm/binconcepts/lstm/raw_full/2022_01_28_0/config.yaml
# There are 2 high performers that are predicted as low performers, and 8 low performers that are predicted as high performers

# %%
cd ../notebooks/5 - training
# Out:
# /Users/cock/kDrive/PhD/Projects/Labs/beerslaw-lab/notebooks/5 - training

# %%
ipyplot.plot_class_tabs(plot_data['high']['addresses'], plot_data['high']['labels'], img_width=1000)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KQ3L5Cx5Qm37VXavmXrgn4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KQ3L5Cx5Qm37VXavmXrgn4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KQ3L5Cx5Qm37VXavmXrgn4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KQ3L5Cx5Qm37VXavmXrgn4:checked ~ #ipyplot-html-viewer-textarea-KQ3L5Cx5Qm37VXavmXrgn4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KQ3L5Cx5Qm37VXavmXrgn4:checked + #ipyplot-html-viewer-label-KQ3L5Cx5Qm37VXavmXrgn4:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-KQ3L5Cx5Qm37VXavmXrgn4">
#         <label id="ipyplot-html-viewer-label-KQ3L5Cx5Qm37VXavmXrgn4" for="ipyplot-html-viewer-toggle-KQ3L5Cx5Qm37VXavmXrgn4">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-KQ3L5Cx5Qm37VXavmXrgn4" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF {
#                 display: none;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF + label.ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF:checked + label.ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF ~ .tab {
#                 display: none
#             }
#     #tabFBmPAjLfMQWvLgzgtuh5Sm:checked ~ .tab.contentFBmPAjLfMQWvLgzgtuh5Sm,#tabnhE6EdSdjg7sCyWFwLHJDb:checked ~ .tab.contentnhE6EdSdjg7sCyWFwLHJDb{ display: block; }</style><input class="ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF" type="radio" name="tabs-kF3ESyVBHNTfv7dFpmL9nF" id="tabFBmPAjLfMQWvLgzgtuh5Sm" checked /><label class="ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF" for="tabFBmPAjLfMQWvLgzgtuh5Sm">high (good)</label><input class="ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF" type="radio" name="tabs-kF3ESyVBHNTfv7dFpmL9nF" id="tabnhE6EdSdjg7sCyWFwLHJDb"/><label class="ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF" for="tabnhE6EdSdjg7sCyWFwLHJDb">low (wrong)</label><div class="tab contentFBmPAjLfMQWvLgzgtuh5Sm">
#         <style>
#         #ipyplot-imgs-container-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3ffwJ7BeeJM8C9hUmTWMds">
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-Ui6JA8kyZFrbVks64MrXk4" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l3vsn2h9f_t2.png</h4><img src="./colour timelines/p2031_l3vsn2h9f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-Ui6JA8kyZFrbVks64MrXk4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-endUQStgYUM9ijFUDQdWFB" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_leau7bsmq_t2.png</h4><img src="./colour timelines/p2031_leau7bsmq_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-endUQStgYUM9ijFUDQdWFB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-ZNdisxykw6w63Qx4Bw9Dj6" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l5zrt4f8z_t2.png</h4><img src="./colour timelines/p2031_l5zrt4f8z_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-ZNdisxykw6w63Qx4Bw9Dj6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-WwzYjecgzNwp2zqZRkfEEZ" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wr
# <div>
#         <style>
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF {
#                 display: none;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF + label.ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF:checked + label.ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF ~ .tab {
#                 display: none
#             }
#     #tabFBmPAjLfMQWvLgzgtuh5Sm:checked ~ .tab.contentFBmPAjLfMQWvLgzgtuh5Sm,#tabnhE6EdSdjg7sCyWFwLHJDb:checked ~ .tab.contentnhE6EdSdjg7sCyWFwLHJDb{ display: block; }</style><input class="ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF" type="radio" name="tabs-kF3ESyVBHNTfv7dFpmL9nF" id="tabFBmPAjLfMQWvLgzgtuh5Sm" checked /><label class="ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF" for="tabFBmPAjLfMQWvLgzgtuh5Sm">high (good)</label><input class="ipyplot-tab-kF3ESyVBHNTfv7dFpmL9nF" type="radio" name="tabs-kF3ESyVBHNTfv7dFpmL9nF" id="tabnhE6EdSdjg7sCyWFwLHJDb"/><label class="ipyplot-tab-label-kF3ESyVBHNTfv7dFpmL9nF" for="tabnhE6EdSdjg7sCyWFwLHJDb">low (wrong)</label><div class="tab contentFBmPAjLfMQWvLgzgtuh5Sm">
#         <style>
#         #ipyplot-imgs-container-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3ffwJ7BeeJM8C9hUmTWMds">
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-Ui6JA8kyZFrbVks64MrXk4" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l3vsn2h9f_t2.png</h4><img src="./colour timelines/p2031_l3vsn2h9f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-Ui6JA8kyZFrbVks64MrXk4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-endUQStgYUM9ijFUDQdWFB" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_leau7bsmq_t2.png</h4><img src="./colour timelines/p2031_leau7bsmq_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-endUQStgYUM9ijFUDQdWFB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-ZNdisxykw6w63Qx4Bw9Dj6" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l5zrt4f8z_t2.png</h4><img src="./colour timelines/p2031_l5zrt4f8z_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-ZNdisxykw6w63Qx4Bw9Dj6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-WwzYjecgzNwp2zqZRkfEEZ" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_lrgeb7wr9_t2.png</h4><img src="./colour timelines/p2031_lrgeb7wr9_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-WwzYjecgzNwp2zqZRkfEEZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-jTSAzZSQzqEL2XLk2UzjeL" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2031_l4k4kc2k6_t2.png</h4><img src="./colour timelines/p2031_l4k4kc2k6_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-jTSAzZSQzqEL2XLk2UzjeL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3ffwJ7BeeJM8C9hUmTWMds">
#         <div id="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds-GPKiVbo3RoSmWH3xySAx8F" class="ipyplot-content-div-3ffwJ7BeeJM8C9hUmTWMds">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%

# %%
ipyplot.plot_class_tabs(plot_data['low']['addresses'], plot_data['low']['labels'], img_width=1000)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-9whQBtHSaBzsaBkh9o9gXN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9whQBtHSaBzsaBkh9o9gXN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9whQBtHSaBzsaBkh9o9gXN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9whQBtHSaBzsaBkh9o9gXN:checked ~ #ipyplot-html-viewer-textarea-9whQBtHSaBzsaBkh9o9gXN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9whQBtHSaBzsaBkh9o9gXN:checked + #ipyplot-html-viewer-label-9whQBtHSaBzsaBkh9o9gXN:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9whQBtHSaBzsaBkh9o9gXN">
#         <label id="ipyplot-html-viewer-label-9whQBtHSaBzsaBkh9o9gXN" for="ipyplot-html-viewer-toggle-9whQBtHSaBzsaBkh9o9gXN">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9whQBtHSaBzsaBkh9o9gXN" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU {
#                 display: none;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU + label.ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU:checked + label.ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU ~ .tab {
#                 display: none
#             }
#     #tabjqYUu8RPwQNMXgThadsPcq:checked ~ .tab.contentjqYUu8RPwQNMXgThadsPcq,#tabAU3nX5dXrmzFxocYQZk5Ks:checked ~ .tab.contentAU3nX5dXrmzFxocYQZk5Ks{ display: block; }</style><input class="ipyplot-tab-AYgkCGCBhfYUWfuK292zFU" type="radio" name="tabs-AYgkCGCBhfYUWfuK292zFU" id="tabjqYUu8RPwQNMXgThadsPcq" checked /><label class="ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU" for="tabjqYUu8RPwQNMXgThadsPcq">high (wrong)</label><input class="ipyplot-tab-AYgkCGCBhfYUWfuK292zFU" type="radio" name="tabs-AYgkCGCBhfYUWfuK292zFU" id="tabAU3nX5dXrmzFxocYQZk5Ks"/><label class="ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU" for="tabAU3nX5dXrmzFxocYQZk5Ks">low (good)</label><div class="tab contentjqYUu8RPwQNMXgThadsPcq">
#         <style>
#         #ipyplot-imgs-container-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bqmCuGneF3CdTpnRuALVwb">
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-JfZrtsWXHWAyxMDik9SCjS" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p0312_lqsd9cb5e_t2.png</h4><img src="./colour timelines/p0312_lqsd9cb5e_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-JfZrtsWXHWAyxMDik9SCjS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-HEvCfRR9MPS9zb2CSqQLp3" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2103_lwktpsvp8_t2.png</h4><img src="./colour timelines/p2103_lwktpsvp8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-HEvCfRR9MPS9zb2CSqQLp3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-WGsENRRS5LWYpoRbZoDB3d" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3021_l7xhcecye_t2.png</h4><img src="./colour timelines/p3021_l7xhcecye_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-WGsENRRS5LWYpoRbZoDB3d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-QKFVVmnm7yEDqckX34JjYg" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wr
# <div>
#         <style>
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU {
#                 display: none;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU + label.ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU:checked + label.ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-AYgkCGCBhfYUWfuK292zFU ~ .tab {
#                 display: none
#             }
#     #tabjqYUu8RPwQNMXgThadsPcq:checked ~ .tab.contentjqYUu8RPwQNMXgThadsPcq,#tabAU3nX5dXrmzFxocYQZk5Ks:checked ~ .tab.contentAU3nX5dXrmzFxocYQZk5Ks{ display: block; }</style><input class="ipyplot-tab-AYgkCGCBhfYUWfuK292zFU" type="radio" name="tabs-AYgkCGCBhfYUWfuK292zFU" id="tabjqYUu8RPwQNMXgThadsPcq" checked /><label class="ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU" for="tabjqYUu8RPwQNMXgThadsPcq">high (wrong)</label><input class="ipyplot-tab-AYgkCGCBhfYUWfuK292zFU" type="radio" name="tabs-AYgkCGCBhfYUWfuK292zFU" id="tabAU3nX5dXrmzFxocYQZk5Ks"/><label class="ipyplot-tab-label-AYgkCGCBhfYUWfuK292zFU" for="tabAU3nX5dXrmzFxocYQZk5Ks">low (good)</label><div class="tab contentjqYUu8RPwQNMXgThadsPcq">
#         <style>
#         #ipyplot-imgs-container-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 1000px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb {
#             width: 1000px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb img {
#             width: 1000px;
#         }
#
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bqmCuGneF3CdTpnRuALVwb">
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-JfZrtsWXHWAyxMDik9SCjS" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p0312_lqsd9cb5e_t2.png</h4><img src="./colour timelines/p0312_lqsd9cb5e_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-JfZrtsWXHWAyxMDik9SCjS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-HEvCfRR9MPS9zb2CSqQLp3" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2103_lwktpsvp8_t2.png</h4><img src="./colour timelines/p2103_lwktpsvp8_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-HEvCfRR9MPS9zb2CSqQLp3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-WGsENRRS5LWYpoRbZoDB3d" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3021_l7xhcecye_t2.png</h4><img src="./colour timelines/p3021_l7xhcecye_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-WGsENRRS5LWYpoRbZoDB3d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-QKFVVmnm7yEDqckX34JjYg" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p3201_lszvqb37f_t2.png</h4><img src="./colour timelines/p3201_lszvqb37f_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-QKFVVmnm7yEDqckX34JjYg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-kU9Feex5xsspucaSMKmyt9" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">./colour timelines/p2301_l84nmc3df_t2.png</h4><img src="./colour timelines/p2301_l84nmc3df_t2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-kU9Feex5xsspucaSMKmyt9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bqmCuGneF3CdTpnRuALVwb">
#         <div id="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb-NzsZ6z2VQbVgWCLS3saye3" class="ipyplot-content-div-bqmCuGneF3CdTpnRuALVwb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%

# %% [markdown]
# ## Sample

# %%
cd ../../src
experiment = '../experiments/real_nested/baselines/simplestate_secondslstm/binconcepts/lstm/raw_full/2022_01_28_0/'
plot_data = get_highlow(experiment, xval_plotter)
cd ../notebooks/5 - training
ipyplot.plot_class_tabs(plot_data['high']['addresses'], plot_data['high']['labels'], img_width=1000)
